# %%
import numpy as np
import pandas as pd
import scipy.io as sio
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from scipy.signal import butter, filtfilt, resample, welch
from scipy.fft import fft, fftfreq, ifft

from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam

import datetime
import time
import sys
import os

# %%
data_path = './bidmc/bidmc_data.mat'
figures_path = './figures'

# %% [markdown]
# # **Kiểm Tra cấu trúc của dữ liệu**

# %%
# Tải dữ liệu
print("Đang tải dữ liệu từ file .mat...")
mat_data = sio.loadmat(data_path)

# Kiểm tra cấu trúc dữ liệu
print("Các khóa trong file .mat:")
for key in mat_data.keys():
    print(f"- {key}")

# Kiểm tra cấu trúc chi tiết
if 'data' in mat_data:
    data = mat_data['data']
    print(f"\nKiểu dữ liệu của 'data': {type(data)}")
    print(f"Kích thước của 'data': {data.shape}")
    
    # Kiểm tra cấu trúc của phần tử đầu tiên nếu data là mảng
    if isinstance(data, np.ndarray) and data.size > 0:
        first_record = data[0]
        if hasattr(first_record, 'dtype') and hasattr(first_record.dtype, 'names'):
            print("\nCác trường trong bản ghi đầu tiên:")
            for field in first_record.dtype.names:
                print(f"- {field}")
                
                # Kiểm tra cấu trúc chi tiết của từng trường
                field_data = first_record[field]
                print(f"  Kiểu: {type(field_data)}, Kích thước: {field_data.shape}")
                
                # Nếu là mảng có cấu trúc, hiển thị thêm thông tin
                if hasattr(field_data, 'dtype') and hasattr(field_data.dtype, 'names'):
                    print(f"  Các trường con: {field_data.dtype.names}")
        else:
            print(f"\nPhần tử đầu tiên không có cấu trúc trường, kiểu: {type(first_record)}")
    else:
        print("\nKhông thể truy cập phần tử đầu tiên của 'data'")
else:
    print("\nKhông tìm thấy khóa 'data' trong file .mat")
    print("Đang kiểm tra cấu trúc dữ liệu thay thế...")
    
    # Tìm khóa có thể chứa dữ liệu chính
    potential_data_keys = [k for k in mat_data.keys() if not k.startswith('__')]
    for key in potential_data_keys:
        print(f"\nKiểm tra khóa: {key}")
        data_item = mat_data[key]
        print(f"Kiểu: {type(data_item)}, ", end="")
        
        if isinstance(data_item, np.ndarray):
            print(f"Kích thước: {data_item.shape}")
            
            # Kiểm tra nếu là mảng có cấu trúc
            if data_item.dtype.names is not None:
                print(f"Các trường: {data_item.dtype.names}")
            
            # Kiểm tra phần tử đầu tiên nếu là mảng nhiều chiều
            if data_item.size > 0:
                first_item = data_item[0]
                print(f"Kiểu phần tử đầu tiên: {type(first_item)}")
                
                # Nếu phần tử đầu tiên là mảng có cấu trúc
                if hasattr(first_item, 'dtype') and hasattr(first_item.dtype, 'names'):
                    print(f"Các trường trong phần tử đầu tiên: {first_item.dtype.names}")
        else:
            print(f"Không phải mảng numpy")

print("\nĐang lưu thông tin cấu trúc dữ liệu vào file...")
with open(os.path.join(figures_path, 'data_structure.txt'), 'w', encoding='utf-8') as f:
    f.write("CẤU TRÚC DỮ LIỆU BIDMC PPG AND RESPIRATION DATASET\n")
    f.write("=================================================\n\n")
    
    f.write("Các khóa trong file .mat:\n")
    for key in mat_data.keys():
        f.write(f"- {key}\n")
    
    f.write("\nThông tin chi tiết về cấu trúc dữ liệu được lưu trong file này.")
# Out:
# Đang tải dữ liệu từ file .mat...
# Các khóa trong file .mat:
# - __header__
# - __version__
# - __globals__
# - data
#
# Kiểu dữ liệu của 'data': <class 'numpy.ndarray'>
# Kích thước của 'data': (1, 53)
#
# Các trường trong bản ghi đầu tiên:
# - fix
#   Kiểu: <class 'numpy.ndarray'>, Kích thước: (53,)
#   Các trường con: None
# - ppg
#   Kiểu: <class 'numpy.ndarray'>, Kích thước: (53,)
#   Các trường con: None
# - ekg
#   Kiểu: <class 'numpy.ndarray'>, Kích thước: (53,)
#   Các trường con: None
# - ref
#   Kiểu: <class 'numpy.ndarray'>, Kích thước: (53,)
#   Các trường con: None
#
# Đang lưu thông tin cấu trúc dữ liệu vào file...

# %% [markdown]
# # **Khám phá dữ liệu**

# %%
os.makedirs(figures_path, exist_ok=True)

# Tải dữ liệu
print("Đang tải dữ liệu từ file .mat...")
mat_data = sio.loadmat(data_path)
data = mat_data['data'][0]  # Lấy mảng chính chứa 53 bản ghi

# Khám phá cấu trúc dữ liệu
print(f"Số lượng bản ghi: {len(data)}")

# Khám phá cấu trúc chi tiết của bản ghi đầu tiên
first_record = data[0]
print("\nKhám phá cấu trúc chi tiết của bản ghi đầu tiên:")

# Kiểm tra cấu trúc của trường ppg
ppg_field = first_record['ppg'][0, 0]
print(f"Cấu trúc của trường ppg: {type(ppg_field)}")
if hasattr(ppg_field, 'dtype') and hasattr(ppg_field.dtype, 'names'):
    print(f"Các trường con của ppg: {ppg_field.dtype.names}")

# Kiểm tra cấu trúc của trường ref
ref_field = first_record['ref'][0, 0]
print(f"Cấu trúc của trường ref: {type(ref_field)}")
if hasattr(ref_field, 'dtype') and hasattr(ref_field.dtype, 'names'):
    print(f"Các trường con của ref: {ref_field.dtype.names}")
    
    # Kiểm tra cấu trúc của trường params trong ref
    if 'params' in ref_field.dtype.names:
        params_field = ref_field['params'][0, 0]
        print(f"Cấu trúc của trường params: {type(params_field)}")
        if hasattr(params_field, 'dtype') and hasattr(params_field.dtype, 'names'):
            print(f"Các trường con của params: {params_field.dtype.names}")

# Kiểm tra chi tiết hơn về cấu trúc dữ liệu
print("\nKiểm tra chi tiết hơn về cấu trúc dữ liệu:")
print(f"Kiểu dữ liệu của ppg.v: {type(first_record['ppg'][0, 0]['v'])}")
print(f"Kích thước của ppg.v: {first_record['ppg'][0, 0]['v'].shape}")
print(f"Kiểu dữ liệu của ref.params.hr: {type(first_record['ref'][0, 0]['params'][0, 0]['hr'])}")
print(f"Kích thước của ref.params.hr: {first_record['ref'][0, 0]['params'][0, 0]['hr'].shape}")
# Out:
# Đang tải dữ liệu từ file .mat...
# Số lượng bản ghi: 53
#
# Khám phá cấu trúc chi tiết của bản ghi đầu tiên:
# Cấu trúc của trường ppg: <class 'numpy.void'>
# Các trường con của ppg: ('v', 'fs', 'method')
# Cấu trúc của trường ref: <class 'numpy.void'>
# Các trường con của ref: ('resp_sig', 'breaths', 'params')
# Cấu trúc của trường params: <class 'numpy.void'>
# Các trường con của params: ('rr', 'hr', 'pr', 'spo2')
#
# Kiểm tra chi tiết hơn về cấu trúc dữ liệu:
# Kiểu dữ liệu của ppg.v: <class 'numpy.ndarray'>
# Kích thước của ppg.v: (60001, 1)
# Kiểu dữ liệu của ref.params.hr: <class 'numpy.ndarray'>
# Kích thước của ref.params.hr: (1, 1)

# %%
# Trích xuất và vẽ tín hiệu PPG từ bản ghi đầu tiên
try:
    # Truy cập trực tiếp vào dữ liệu PPG
    ppg_data = first_record['ppg'][0, 0]['v']
    if isinstance(ppg_data, np.ndarray):
        # Nếu là mảng numpy, lấy dữ liệu trực tiếp
        sample_ppg = ppg_data.flatten()
    else:
        # Nếu không phải mảng numpy, chuyển đổi thành mảng
        sample_ppg = np.array(ppg_data, dtype=float).flatten()
    
    # Lấy tần số lấy mẫu
    sample_fs_ppg = float(first_record['ppg'][0, 0]['fs'][0, 0])
    
    resp_data = first_record['ref'][0, 0]['resp_sig'][0, 0]['imp'][0, 0]['v']
    if isinstance(resp_data, np.ndarray):
        sample_resp = resp_data.flatten()
    else:
        sample_resp = np.array(resp_data, dtype=float).flatten()
    
    sample_fs_resp = float(first_record['ref'][0, 0]['resp_sig'][0, 0]['imp'][0, 0]['fs'][0, 0])

    print(f"\nTần số lấy mẫu PPG: {sample_fs_ppg} Hz")
    print(f"Tần số lấy mẫu Resp: {sample_fs_resp} Hz")

    print(f"Độ dài tín hiệu PPG: {len(sample_ppg)} mẫu")
    print(f"Độ dài tín hiệu Resp: {len(sample_resp)} mẫu")

    # Tính thời gian cho trục x
    time_ppg = np.arange(len(sample_ppg)) / sample_fs_ppg
    time_resp = np.arange(len(sample_resp)) / sample_fs_resp

    # Vẽ tín hiệu mẫu
    plt.figure(figsize=(15, 10))

    plt.subplot(3, 1, 2)
    plt.plot(time_ppg[:1000], sample_ppg[:1000])
    plt.title('PPG Signal (First Record - First 1000 samples)')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')

    plt.subplot(3, 1, 3)
    plt.plot(time_resp[:1000], sample_resp[:1000])
    plt.title('Respiratory Signal (First Record - First 1000 samples)')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')

    plt.tight_layout()
    plt.savefig(os.path.join(figures_path, 'sample_signals.png'))
    plt.show()
    
    # Phân tích phổ tần số của tín hiệu PPG
    def plot_fft(signal, fs, title, filename):
        N = len(signal)
        T = 1.0 / fs
        yf = fft(signal)
        xf = fftfreq(N, T)[:N//2]
        
        plt.figure(figsize=(10, 6))
        plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
        plt.grid(True, alpha=0.3)
        plt.title(f'FFT of {title}')
        plt.xlabel('Frequency (Hz)')
        plt.ylabel('Amplitude')
        plt.xlim(0, 5)  # Giới hạn tần số hiển thị đến 5Hz
        plt.savefig(os.path.join(figures_path, filename))
        plt.show()

    # Phân tích phổ tần số của tín hiệu PPG, ECG và Resp
    plot_fft(sample_ppg, sample_fs_ppg, 'PPG Signal', 'ppg_fft.png')
    plot_fft(sample_resp, sample_fs_resp, 'Respiratory Signal', 'resp_fft.png')
    
except Exception as e:
    print(f"Lỗi khi vẽ tín hiệu mẫu: {e}")
# Out:
# Tần số lấy mẫu PPG: 125.0 Hz
# Tần số lấy mẫu Resp: 125.0 Hz
# Độ dài tín hiệu PPG: 60001 mẫu
# Độ dài tín hiệu Resp: 60001 mẫu

# %% [markdown]
# **Giá trị của HR RR được lưu trong file .log**

# %%
# Kiểm tra trực tiếp một số bản ghi để tìm hiểu cấu trúc HR và RR
logging.basicConfig(filename='preprocessing.log', level=logging.INFO, encoding='utf-8')

print("\nKiểm tra trực tiếp HR và RR từ một số bản ghi:")
for i in range(min(5, len(data))):
    try:
        record = data[i]
        params = record['ref'][0, 0]['params'][0, 0]
        
        hr_data = params['hr'][0]
        rr_data = params['rr'][0]
        
        print(f"\nBản ghi {i}:")
        print(f"Kiểu dữ liệu HR: {type(hr_data)}")
        if hasattr(hr_data, 'dtype'):
            print(f"Dtype của HR: {hr_data.dtype}")
        if hasattr(hr_data, 'shape'):
            print(f"Kích thước của HR: {hr_data.shape}")
        
        print(f"Kiểu dữ liệu RR: {type(rr_data)}")
        if hasattr(rr_data, 'dtype'):
            print(f"Dtype của RR: {rr_data.dtype}")
        if hasattr(rr_data, 'shape'):
            print(f"Kích thước của RR: {rr_data.shape}")
        
        if hasattr(hr_data, 'size') and hr_data.size > 0:
            if hasattr(hr_data, 'dtype') and hr_data.dtype.names is not None and 'v' in hr_data.dtype.names:
                logging.info(f"Giá trị HR đầu tiên (trường v): {hr_data['v'][0] if hr_data['v'].size > 0 else 'Không có dữ liệu'}")
            else:
                logging.info(f"Giá trị HR đầu tiên: {hr_data[0]}")
        
        if hasattr(rr_data, 'size') and rr_data.size > 0:
            if hasattr(rr_data, 'dtype') and rr_data.dtype.names is not None and 'v' in rr_data.dtype.names:
                logging.info(f"Giá trị RR đầu tiên (trường v): {rr_data['v'][0] if rr_data['v'].size > 0 else 'Không có dữ liệu'}")
            else:
                logging.info(f"Giá trị RR đầu tiên: {rr_data[0]}")
    except Exception as e:
        print(f"Lỗi khi kiểm tra bản ghi {i}: {e}")
# Out:
# Kiểm tra trực tiếp HR và RR từ một số bản ghi:
#
# Bản ghi 0:
# Kiểu dữ liệu HR: <class 'numpy.ndarray'>
# Dtype của HR: [('t', 'O'), ('v', 'O'), ('method', 'O'), ('units', 'O')]
# Kích thước của HR: (1,)
# Kiểu dữ liệu RR: <class 'numpy.ndarray'>
# Dtype của RR: [('t', 'O'), ('v', 'O'), ('method', 'O'), ('units', 'O')]
# Kích thước của RR: (1,)
#
# Bản ghi 1:
# Kiểu dữ liệu HR: <class 'numpy.ndarray'>
# Dtype của HR: [('t', 'O'), ('v', 'O'), ('method', 'O'), ('units', 'O')]
# Kích thước của HR: (1,)
# Kiểu dữ liệu RR: <class 'numpy.ndarray'>
# Dtype của RR: [('t', 'O'), ('v', 'O'), ('method', 'O'), ('units', 'O')]
# Kích thước của RR: (1,)
#
# Bản ghi 2:
# Kiểu dữ liệu HR: <class 'numpy.ndarray'>
# Dtype của HR: [('t', 'O'), ('v', 'O'), ('method', 'O'), ('units', 'O')]
# Kích thước của HR: (1,)
# Kiểu dữ liệu RR: <class 'numpy.ndarray'>
# Dtype của RR: [('t', 'O'), ('v', 'O'), ('method', 'O'), ('units', 'O')]
# Kích thước của RR: (1,)
#
# Bản ghi 3:
# Kiểu dữ liệu HR: <class 'numpy.ndarray'>
# Dtype của HR: [('t', 'O'), ('v', 'O'), ('method', 'O'), ('units', 'O')]
# Kích thước của HR: (1,)
# Kiểu dữ liệu RR: <class 'numpy.ndarray'>
# Dtype của RR: [('t', 'O'), ('v', 'O'), ('method', 'O'), ('units', 'O')]
# Kích thước của RR: (1,)
#
# Bản ghi 4:
# Kiểu dữ liệu HR: <class 'numpy.ndarray'>
# Dtype của HR: [('t', 'O'), ('v', 'O'), ('method', 'O'), ('units', 'O')]
# Kích thước của HR: (1,)
# Kiểu dữ liệu RR: <class 'numpy.ndarray'>
# Dtype của RR: [('t', 'O'), ('v', 'O'), ('method', 'O'), ('units', 'O')]
# Kích thước của RR: (1,)

# %% [markdown]
# # **Xử lý dữ liệu**

# %%
processed_data_path = './processed'
# Tạo thư mục nếu chưa tồn tại
os.makedirs(processed_data_path, exist_ok=True)
os.makedirs(figures_path, exist_ok=True)

# Tải dữ liệu
print("Đang tải dữ liệu từ file .mat...")
mat_data = sio.loadmat(data_path)
data = mat_data['data'][0]  # Lấy mảng chính chứa 53 bản ghi

print(f"Số lượng bản ghi: {len(data)}")

# Hàm lọc nhiễu cho tín hiệu PPG
def butter_bandpass_filter(data, lowcut, highcut, fs, order=2):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = filtfilt(b, a, data)
    return y

# Hàm chuẩn hóa tín hiệu
def normalize_signal(signal, method='minmax'):
    if method == 'minmax':
        scaler = MinMaxScaler(feature_range=(-1, 1))
        signal_reshaped = signal.reshape(-1, 1)
        normalized = scaler.fit_transform(signal_reshaped).flatten()
    elif method == 'standard':
        scaler = StandardScaler()
        signal_reshaped = signal.reshape(-1, 1)
        normalized = scaler.fit_transform(signal_reshaped).flatten()
    elif method == 'simple':
        normalized = (signal - np.mean(signal)) / np.std(signal)
    else:
        raise ValueError("Phương pháp chuẩn hóa không hợp lệ")
    return normalized

# Hàm chia tín hiệu thành các đoạn có độ dài cố định
def segment_signal(signal, segment_length, overlap=0):
    step = int(segment_length * (1 - overlap))
    segments = []
    for i in range(0, len(signal) - segment_length + 1, step):
        segments.append(signal[i:i + segment_length])
    return np.array(segments)

# Hàm trích xuất đặc trưng HR và BR từ tín hiệu
def extract_hr_br_features(hr_values, rr_values):
    # Lấy giá trị trung bình của HR và BR
    hr_mean = np.nanmean(hr_values)
    rr_mean = np.nanmean(rr_values)
    
    # Thay thế NaN bằng giá trị trung bình
    hr_values = np.where(np.isnan(hr_values), hr_mean, hr_values)
    rr_values = np.where(np.isnan(rr_values), rr_mean, rr_values)
    
    # Lấy giá trị trung bình mới
    hr_mean = np.mean(hr_values)
    rr_mean = np.mean(rr_values)
    return hr_mean, rr_mean
# Out:
# Đang tải dữ liệu từ file .mat...
# Số lượng bản ghi: 53

# %%
# Danh sách để lưu trữ dữ liệu đã tiền xử lý
ppg_segments = []
hr_features = []
rr_features = []

# Tham số tiền xử lý
fs = 125  # Tần số lấy mẫu (Hz)
segment_length = 8 * fs  # Độ dài đoạn tín hiệu (8 giây)
overlap = 0.5  # Độ chồng lấp giữa các đoạn (50%)
lowcut = 0.5  # Tần số cắt dưới cho bộ lọc (Hz)
highcut = 8.0  # Tần số cắt trên cho bộ lọc (Hz)

# Tiền xử lý dữ liệu từ mỗi bản ghi
valid_records = 0
for i in range(len(data)):
    try:
        record = data[i]
        
        # Trích xuất tín hiệu PPG
        ppg_data = record['ppg'][0, 0]['v']
        if isinstance(ppg_data, np.ndarray):
            ppg_signal = ppg_data.flatten()
        else:
            ppg_signal = np.array(ppg_data, dtype=float).flatten()
        
        # Trích xuất HR và RR - Truy cập trực tiếp vào giá trị số trong mảng
        try:
            # Trích xuất HR từ mảng lồng nhau
            hr_data = record['ref'][0, 0]['params'][0, 0]['hr'][0]
            if hasattr(hr_data, 'dtype') and hr_data.dtype.names is not None and 'v' in hr_data.dtype.names:
                hr_values_raw = hr_data['v']
            else:
                hr_values_raw = hr_data
                
            # Trích xuất RR từ mảng lồng nhau
            rr_data = record['ref'][0, 0]['params'][0, 0]['rr'][0]
            if hasattr(rr_data, 'dtype') and rr_data.dtype.names is not None and 'v' in rr_data.dtype.names:
                rr_values_raw = rr_data['v']
            else:
                rr_values_raw = rr_data
            
            # Trích xuất giá trị số từ mảng lồng nhau
            hr_values = []
            for item in hr_values_raw:
                if isinstance(item, np.ndarray):
                    if item.size == 1:
                        hr_values.append(float(item.item()))  # Lấy phần tử duy nhất
                    else:
                        hr_values.extend(item.astype(float).flatten())  # Nếu có nhiều phần tử, thêm tất cả
                elif np.isscalar(item):
                    hr_values.append(float(item))

            
            rr_values = []
            for item in rr_values_raw:
                if isinstance(item, np.ndarray):
                    if item.size == 1:
                        rr_values.append(float(item.item()))
                    else:
                        rr_values.extend(item.astype(float).flatten())
                elif np.isscalar(item):
                    rr_values.append(float(item))


            
            # Kiểm tra xem có đủ dữ liệu không
            if len(hr_values) == 0 or len(rr_values) == 0:
                print(f"Không đủ dữ liệu HR/RR cho bản ghi {i}, bỏ qua bản ghi này")
                continue
                
        except Exception as e:
            print(f"Lỗi khi trích xuất HR/RR của bản ghi {i}: {e}, bỏ qua bản ghi này")
            continue
        
        # Lọc nhiễu tín hiệu PPG
        ppg_filtered = butter_bandpass_filter(ppg_signal, lowcut, highcut, fs)
        
        # Chuẩn hóa tín hiệu PPG
        ppg_normalized = normalize_signal(ppg_filtered, method='minmax')
        
        # Chia tín hiệu thành các đoạn
        segments = segment_signal(ppg_normalized, segment_length, overlap)
        
        # Trích xuất đặc trưng HR và BR cho mỗi đoạn
        for segment in segments:
            hr_feature, rr_feature = extract_hr_br_features(hr_values, rr_values)
            
            # Thêm vào danh sách
            ppg_segments.append(segment)
            hr_features.append(hr_feature)
            rr_features.append(rr_feature)
        
        valid_records += 1
        print(f"Đã xử lý bản ghi {i}, số đoạn tín hiệu: {len(segments)}")
        
    except Exception as e:
        print(f"Lỗi khi xử lý bản ghi {i}: {e}")

print(f"\nĐã xử lý thành công {valid_records}/{len(data)} bản ghi")
print(f"Tổng số đoạn tín hiệu: {len(ppg_segments)}")
# Out:
# Đã xử lý bản ghi 0, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 1, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 2, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 3, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 4, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 5, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 6, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 7, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 8, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 9, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 10, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 11, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 12, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 13, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 14, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 15, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 16, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 17, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 18, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 19, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 20, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 21, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 22, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 23, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 24, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 25, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 26, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 27, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 28, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 29, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 30, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 31, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 32, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 33, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 34, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 35, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 36, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 37, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 38, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 39, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 40, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 41, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 42, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 43, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 44, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 45, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 46, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 47, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 48, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 49, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 50, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 51, số đoạn tín hiệu: 119
# Đã xử lý bản ghi 52, số đoạn tín hiệu: 119
#
# Đã xử lý thành công 53/53 bản ghi
# Tổng số đoạn tín hiệu: 6307

# %%
# Kiểm tra xem có đủ dữ liệu không
if len(ppg_segments) == 0:
    print("Không có đủ dữ liệu để tiếp tục. Sử dụng dữ liệu giả lập để minh họa.")
    
    # Tạo dữ liệu giả lập để minh họa
    num_samples = 100
    ppg_segments = np.random.randn(num_samples, segment_length) * 0.1
    hr_features = np.random.uniform(0.3, 0.6, num_samples)  # HR từ 60-120 bpm (chuẩn hóa)
    rr_features = np.random.uniform(0.1, 0.3, num_samples)  # RR từ 6-18 breaths/min (chuẩn hóa)
    
    print(f"Đã tạo {num_samples} mẫu dữ liệu giả lập.")

# Chuyển đổi danh sách thành mảng numpy
ppg_segments = np.array(ppg_segments)
hr_features = np.array(hr_features)
rr_features = np.array(rr_features)

# Chia dữ liệu thành tập huấn luyện và tập kiểm thử
X_train, X_test, hr_train, hr_test, rr_train, rr_test = train_test_split(
    ppg_segments, hr_features, rr_features, test_size=0.2, random_state=42
)

# Lưu dữ liệu đã tiền xử lý
np.save(os.path.join(processed_data_path, 'ppg_train.npy'), X_train)
np.save(os.path.join(processed_data_path, 'ppg_test.npy'), X_test)
np.save(os.path.join(processed_data_path, 'hr_train.npy'), hr_train)
np.save(os.path.join(processed_data_path, 'hr_test.npy'), hr_test)
np.save(os.path.join(processed_data_path, 'rr_train.npy'), rr_train)
np.save(os.path.join(processed_data_path, 'rr_test.npy'), rr_test)

# Lưu thông tin về dữ liệu đã tiền xử lý
with open(os.path.join(processed_data_path, 'preprocessing_info.txt'), 'w', encoding='utf-8') as f:
    f.write("THÔNG TIN TIỀN XỬ LÝ DỮ LIỆU\n")
    f.write("============================\n\n")
    
    f.write(f"Số lượng bản ghi đã xử lý: {valid_records}/{len(data)}\n")
    f.write(f"Tổng số đoạn tín hiệu: {len(ppg_segments)}\n\n")
    
    f.write("Tham số tiền xử lý:\n")
    f.write(f"- Tần số lấy mẫu: {fs} Hz\n")
    f.write(f"- Độ dài đoạn tín hiệu: {segment_length} mẫu ({segment_length/fs} giây)\n")
    f.write(f"- Độ chồng lấp: {overlap*100}%\n")
    f.write(f"- Tần số cắt dưới: {lowcut} Hz\n")
    f.write(f"- Tần số cắt trên: {highcut} Hz\n\n")
    
    f.write("Kích thước dữ liệu:\n")
    f.write(f"- Tập huấn luyện: {X_train.shape[0]} mẫu\n")
    f.write(f"- Tập kiểm thử: {X_test.shape[0]} mẫu\n\n")
    
    f.write("Thống kê HR (chuẩn hóa):\n")
    f.write(f"- Min: {np.min(hr_features):.4f}, Max: {np.max(hr_features):.4f}\n")
    f.write(f"- Mean: {np.mean(hr_features):.4f}, Std: {np.std(hr_features):.4f}\n\n")
    
    f.write("Thống kê RR (chuẩn hóa):\n")
    f.write(f"- Min: {np.min(rr_features):.4f}, Max: {np.max(rr_features):.4f}\n")
    f.write(f"- Mean: {np.mean(rr_features):.4f}, Std: {np.std(rr_features):.4f}\n")
    
    if valid_records == 0:
        f.write("\nLưu ý: Dữ liệu được sử dụng là dữ liệu giả lập do không thể trích xuất được dữ liệu thực từ bộ dữ liệu BIDMC.\n")

# %%
# Vẽ biểu đồ phân phối HR và RR đã chuẩn hóa
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(hr_features, bins=30, alpha=0.7, color='blue')
plt.axvline(np.mean(hr_features), color='red', linestyle='dashed', linewidth=1)
plt.title('Normalized Heart Rate Distribution')
plt.xlabel('Normalized Heart Rate')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
plt.hist(rr_features, bins=30, alpha=0.7, color='green')
plt.axvline(np.mean(rr_features), color='red', linestyle='dashed', linewidth=1)
plt.title('Normalized Respiratory Rate Distribution')
plt.xlabel('Normalized Respiratory Rate')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'normalized_hr_rr_distribution.png'))
plt.close()

# Vẽ một số đoạn tín hiệu PPG đã tiền xử lý
plt.figure(figsize=(15, 10))

for i in range(min(5, len(X_train))):
    plt.subplot(5, 1, i+1)
    plt.plot(X_train[i])
    plt.title(f'Preprocessed PPG Segment {i+1}')
    plt.xlabel('Sample')
    plt.ylabel('Amplitude')
    plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'preprocessed_ppg_segments.png'))
plt.show()

print("\nTiền xử lý dữ liệu hoàn tất. Dữ liệu đã được lưu vào thư mục processed.")
# Out:
# Tiền xử lý dữ liệu hoàn tất. Dữ liệu đã được lưu vào thư mục processed.

# %% [markdown]
# # **CVEA Model**

# %%
model_path = './models'
# Tạo thư mục nếu chưa tồn tại
os.makedirs(model_path, exist_ok=True)
os.makedirs(figures_path, exist_ok=True)

# Tải dữ liệu đã tiền xử lý
# Tải dữ liệu đã tiền xử lý
print("Đang tải dữ liệu đã tiền xử lý...")
X_train = np.load(os.path.join(processed_data_path, 'ppg_train.npy'))
X_test = np.load(os.path.join(processed_data_path, 'ppg_test.npy'))
hr_train = np.load(os.path.join(processed_data_path, 'hr_train.npy'))
hr_test = np.load(os.path.join(processed_data_path, 'hr_test.npy'))
rr_train = np.load(os.path.join(processed_data_path, 'rr_train.npy'))
rr_test = np.load(os.path.join(processed_data_path, 'rr_test.npy'))

print(f"Kích thước dữ liệu huấn luyện: {X_train.shape}")
print(f"Kích thước dữ liệu kiểm thử: {X_test.shape}")

# Tham số mô hình
input_dim = X_train.shape[1]  # Độ dài đoạn tín hiệu PPG
condition_dim = 2  # HR và RR
latent_dim = 32  # Kích thước không gian tiềm ẩn
hidden_units = [256, 128, 64]  # Số đơn vị ẩn trong các lớp
batch_size = 64
epochs = 10
learning_rate = 1e-7
# Out:
# Đang tải dữ liệu đã tiền xử lý...
# Kích thước dữ liệu huấn luyện: (5045, 1000)
# Kích thước dữ liệu kiểm thử: (1262, 1000)

# %%
# Định nghĩa lớp Sampling để lấy mẫu từ không gian tiềm ẩn
class Sampling(layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
# Xây dựng Encoder
def build_encoder(input_dim, condition_dim, latent_dim, hidden_units):
        # Đầu vào tín hiệu PPG - cần reshape để phù hợp với Conv1D
        encoder_inputs = layers.Input(shape=(input_dim,), name='encoder_input')
        # Reshape thành (batch_size, input_dim, 1)
        x = layers.Reshape((input_dim, 1))(encoder_inputs)

        # Các lớp Conv1D
        x = layers.Conv1D(filters=64, kernel_size=5, activation='relu', padding='same')(x)
        x = layers.MaxPooling1D(pool_size=2)(x)

        x = layers.Conv1D(filters=128, kernel_size=5, activation='relu', padding='same')(x)
        x = layers.MaxPooling1D(pool_size=2)(x)

        x = layers.Conv1D(filters=256, kernel_size=5, activation='relu', padding='same')(x)
        x = layers.MaxPooling1D(pool_size=2)(x)

        # Flatten để kết nối với các lớp fully-connected
        x = layers.Flatten()(x)

        # Đầu vào điều kiện (HR và RR)
        condition_inputs = layers.Input(shape=(condition_dim,), name='condition_input')

        # Kết hợp đầu vào tín hiệu đã qua xử lý và điều kiện
        x = layers.Concatenate()([x, condition_inputs])

        # Các lớp fully-connected theo yêu cầu
        for units in hidden_units:
            x = layers.Dense(units, activation='relu')(x)

        # Lớp đầu ra
        z_mean = layers.Dense(latent_dim, name='z_mean')(x)
        z_log_var = layers.Dense(latent_dim, name='z_log_var')(x)

        # Lấy mẫu từ không gian tiềm ẩn
        z = Sampling()([z_mean, z_log_var])

        # Định nghĩa mô hình
        encoder = Model([encoder_inputs, condition_inputs], [z_mean, z_log_var, z], name='encoder')

        return encoder

# %%
# Xây dựng Decoder
def build_decoder(latent_dim, condition_dim, input_dim, hidden_units):
    # Đầu vào từ không gian tiềm ẩn
    latent_inputs = layers.Input(shape=(latent_dim,), name='latent_input')

    # Đầu vào điều kiện (HR và RR)
    condition_inputs = layers.Input(shape=(condition_dim,), name='condition_input')

    # Kết hợp đầu vào từ không gian tiềm ẩn và điều kiện
    x = layers.Concatenate()([latent_inputs, condition_inputs])

    # Các lớp ẩn
    for units in reversed(hidden_units):
        x = layers.Dense(units, activation='relu')(x)

    # Lớp đầu ra
    decoder_outputs = layers.Dense(input_dim, activation='tanh')(x)

    # Định nghĩa mô hình
    decoder = Model([latent_inputs, condition_inputs], decoder_outputs, name='decoder')

    return decoder

# %%
# Xây dựng mô hình CVAE
class CVAE(Model):
    def __init__(self, encoder, decoder, **kwargs):
        super(CVAE, self).__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        x, condition = data
        with tf.GradientTape() as tape:
            # Encoder
            z_mean, z_log_var, z = self.encoder([x, condition])

            # Decoder
            reconstruction = self.decoder([z, condition])

            # Tính toán loss
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    tf.keras.losses.mse(x, reconstruction)
                )
            )

            kl_loss = -0.5 * tf.reduce_mean(
                tf.reduce_sum(
                    1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=1
                )
            )

            total_loss = reconstruction_loss + kl_loss

        # Cập nhật trọng số
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))

        # Cập nhật metrics
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)

        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        x, condition = data

        # Encoder
        z_mean, z_log_var, z = self.encoder([x, condition])

        # Decoder
        reconstruction = self.decoder([z, condition])

        # Tính toán loss
        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(
                tf.keras.losses.mse(x, reconstruction)
            )
        )

        kl_loss = -0.5 * tf.reduce_mean(
            tf.reduce_sum(
                1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=1
            )
        )

        total_loss = reconstruction_loss + kl_loss

        # Cập nhật metrics
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)

        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def call(self, inputs):
        x, condition = inputs
        z_mean, z_log_var, z = self.encoder([x, condition])
        reconstruction = self.decoder([z, condition])
        return reconstruction

    def generate(self, condition, z=None):
        if z is None:
            # Tạo vector ngẫu nhiên từ không gian tiềm ẩn
            z = tf.random.normal(shape=(condition.shape[0], latent_dim))

        # Tạo tín hiệu PPG từ vector z và điều kiện
        return self.decoder([z, condition])

# %%
# Xây dựng mô hình
print("Đang xây dựng mô hình CVAE...")
encoder = build_encoder(input_dim, condition_dim, latent_dim, hidden_units)
decoder = build_decoder(latent_dim, condition_dim, input_dim, hidden_units)
cvae = CVAE(encoder, decoder)

# Biên dịch mô hình
cvae.compile(optimizer=Adam(learning_rate=learning_rate))

# Tóm tắt mô hình
print("Tóm tắt mô hình Encoder:")
encoder.summary()
print("\nTóm tắt mô hình Decoder:")
decoder.summary()

# Chuẩn bị dữ liệu điều kiện
condition_train = np.column_stack((hr_train, rr_train))
condition_test = np.column_stack((hr_test, rr_test))

# Tạo TensorBoard callback
log_dir = os.path.join(model_path, "logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# Tạo ModelCheckpoint callback
checkpoint_path = os.path.join(model_path, "cvae_checkpoint.weights.h5")
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True
)

# Tạo EarlyStopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='loss',
    patience=5,
    restore_best_weights=True
)

# Lưu thông tin mô hình
with open(os.path.join(model_path, 'model_info.txt'), 'w',encoding ='utf-8') as f:
    f.write("THÔNG TIN MÔ HÌNH CVAE\n")
    f.write("=====================\n\n")

    f.write("Tham số mô hình:\n")
    f.write(f"- Kích thước đầu vào: {input_dim}\n")
    f.write(f"- Kích thước điều kiện: {condition_dim}\n")
    f.write(f"- Kích thước không gian tiềm ẩn: {latent_dim}\n")
    f.write(f"- Số đơn vị ẩn trong các lớp: {hidden_units}\n")
    f.write(f"- Kích thước batch: {batch_size}\n")
    f.write(f"- Số epoch: {epochs}\n")
    f.write(f"- Tốc độ học: {learning_rate}\n\n")

    f.write("Kích thước dữ liệu:\n")
    f.write(f"- Tập huấn luyện: {X_train.shape[0]} mẫu\n")
    f.write(f"- Tập kiểm thử: {X_test.shape[0]} mẫu\n")

print("\nMô hình CVAE đã được xây dựng thành công.")
print("Thông tin mô hình đã được lưu vào file model_info.txt.")
print("Sẵn sàng để huấn luyện mô hình.")
# Out:
# Đang xây dựng mô hình CVAE...
# Tóm tắt mô hình Encoder:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_input (InputLayer)     [(None, 1000)]       0           []
#
#  reshape_3 (Reshape)            (None, 1000, 1)      0           ['encoder_input[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 1000, 64)     384         ['reshape_3[0][0]']
#
#  max_pooling1d_9 (MaxPooling1D)  (None, 500, 64)     0           ['conv1d_9[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 500, 128)     41088       ['max_pooling1d_9[0][0]']
#
#  max_pooling1d_10 (MaxPooling1D  (None, 250, 128)    0           ['conv1d_10[0][0]']
#  )
#
#  conv1d_11 (Conv1D)             (None, 250, 256)     164096      ['max_pooling1d_10[0][0]']
#
#  max_pooling1d_11 (MaxPooling1D  (None, 125, 256)    0           ['conv1d_11[0][0]']
#  )
#
#  flatten_3 (Flatten)            (None, 32000)        0           ['max_pooling1d_11[0][0]']
#
#  condition_input (InputLayer)   [(None, 2)]          0           []
#
#  concatenate_6 (Concatenate)    (None, 32002)        0           ['flatten_3[0][0]',
#                                                                   'condition_input[0][0]']
#
#  dense_21 (Dense)               (None, 256)          8192768     ['concatenate_6[0][0]']
#
#  dense_22 (Dense)               (None, 128)          32896       ['dense_21[0][0]']
#
#  dense_23 (Dense)               (None, 64)           8256        ['dense_22[0][0]']
#
#  z_mean (Dense)                 (None, 32)           2080        ['dense_23[0][0]']
#
#  z_log_var (Dense)              (None, 32)           2080        ['dense_23[0][0]']
#
#  sampling_3 (Sampling)          (None, 32)           0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 8,443,648
# Trainable params: 8,443,648
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Tóm tắt mô hình Decoder:
# Model: "decoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  latent_input (InputLayer)      [(None, 32)]         0           []
#
#  condition_input (InputLayer)   [(None, 2)]          0           []
#
#  concatenate_7 (Concatenate)    (None, 34)           0           ['latent_input[0][0]',
#                                                                   'condition_input[0][0]']
#
#  dense_24 (Dense)               (None, 64)           2240        ['concatenate_7[0][0]']
#
#  dense_25 (Dense)               (None, 128)          8320        ['dense_24[0][0]']
#
#  dense_26 (Dense)               (None, 256)          33024       ['dense_25[0][0]']
#
#  dense_27 (Dense)               (None, 1000)         257000      ['dense_26[0][0]']
#
# ==================================================================================================
# Total params: 300,584
# Trainable params: 300,584
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Mô hình CVAE đã được xây dựng thành công.
# Thông tin mô hình đã được lưu vào file model_info.txt.
# Sẵn sàng để huấn luyện mô hình.

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print(tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.10.1
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Huấn luyện mô hình
print("\nBắt đầu huấn luyện mô hình...")
start_time = time.time()

# Tạo dataset từ dữ liệu
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, condition_train)).batch(batch_size)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, condition_test)).batch(batch_size)

# Xây dựng mô hình một cách rõ ràng bằng cách truyền dữ liệu mẫu qua nó
for x_batch, c_batch in train_dataset.take(1):
    # Chỉ cần chạy một batch qua mô hình để xây dựng nó
    _ = cvae([x_batch, c_batch])
    break

# Tiếp tục huấn luyện như bình thường
epochs= 500

history = cvae.fit(
    train_dataset,
    epochs=epochs,
    validation_data=test_dataset,
    callbacks=[tensorboard_callback, checkpoint_callback, early_stopping_callback]
)

training_time = time.time() - start_time
print(f"\nHuấn luyện hoàn tất trong {training_time:.2f} giây.")

# Lưu mô hình - bây giờ sẽ hoạt động vì mô hình đã được xây dựng
cvae.save_weights(os.path.join(model_path, 'cvae_final.weights.h5'))
print(f"Đã lưu mô hình tại: {os.path.join(model_path, 'cvae_final.weights.h5')}")
# Out:
# Bắt đầu huấn luyện mô hình...
# Epoch 1/500
# 79/79 [==============================] - 3s 24ms/step - loss: 54.3879 - reconstruction_loss: 49.6533 - kl_loss: 4.5960 - val_loss: 53.4636 - val_reconstruction_loss: 48.9400 - val_kl_loss: 4.5235
# Epoch 2/500
# 79/79 [==============================] - 2s 19ms/step - loss: 54.1474 - reconstruction_loss: 49.5500 - kl_loss: 4.4661 - val_loss: 53.2375 - val_reconstruction_loss: 48.8418 - val_kl_loss: 4.3957
# Epoch 3/500
# 79/79 [==============================] - 2s 20ms/step - loss: 53.9239 - reconstruction_loss: 49.4479 - kl_loss: 4.3393 - val_loss: 53.0339 - val_reconstruction_loss: 48.7614 - val_kl_loss: 4.2725
# Epoch 4/500
# 79/79 [==============================] - 2s 19ms/step - loss: 53.6968 - reconstruction_loss: 49.3477 - kl_loss: 4.2172 - val_loss: 52.8000 - val_reconstruction_loss: 48.6483 - val_kl_loss: 4.1517
# Epoch 5/500
# 79/79 [==============================] - 2s 20ms/step - loss: 53.4709 - reconstruction_loss: 49.2372 - kl_loss: 4.0975 - val_loss: 52.5800 - val_reconstruction_loss: 48.5464 - val_kl_loss: 4.0336
# Epoch 6/500
# 79/79 [==============================] - 2s 20ms/step - loss: 53.2713 - reconstruction_loss: 49.1447 - kl_loss: 3.9807 - val_loss: 52.3595 - val_reconstruction_loss: 48.4404 - val_kl_loss: 3.9190
# Epoch 7/500
# 79/79 [==============================] - 2s 20ms/step - loss: 53.0365 - reconstruction_loss: 49.0375 - kl_loss: 3.8663 - val_loss: 52.1492 - val_reconstruction_loss: 48.3426 - val_kl_loss: 3.8066
# Epoch 8/500
# 79/79 [==============================] - 2s 20ms/step - loss: 52.8112 - reconstruction_loss: 48.9338 - kl_loss: 3.7552 - val_loss: 51.9478 - val_reconstruction_loss: 48.2514 - val_kl_loss: 3.6965
# Epoch 9/500
# 79/79 [==============================] - 2s 21ms/step - loss: 52.6183 - reconstruction_loss: 48.8385 - kl_loss: 3.6455 - val_loss: 51.7298 - val_reconstruction_loss: 48.1412 - val_kl_loss: 3.5886
# Epoch 10/500
# 79/79 [==============================] - 2s 20ms/step - loss: 52.4010 - reconstruction_loss: 48.7349 - kl_loss: 3.5388 - val_loss: 51.5175 - val_reconstruction_loss: 48.0344 - val_kl_loss: 3.4832
# Epoch 11/500
# 79/79 [==============================] - 2s 20ms/step - loss: 52.1963 - reconstruction_loss: 48.6356 - kl_loss: 3.4335 - val_loss: 51.3398 - val_reconstruction_loss: 47.9600 - val_kl_loss: 3.3798
# Epoch 12/500
# 79/79 [==============================] - 2s 20ms/step - loss: 51.9960 - reconstruction_loss: 48.5299 - kl_loss: 3.3318 - val_loss: 51.1063 - val_reconstruction_loss: 47.8264 - val_kl_loss: 3.2799
# Epoch 13/500
# 79/79 [==============================] - 1s 19ms/step - loss: 51.7748 - reconstruction_loss: 48.4199 - kl_loss: 3.2323 - val_loss: 50.9267 - val_reconstruction_loss: 47.7455 - val_kl_loss: 3.1812
# Epoch 14/500
# 79/79 [==============================] - 2s 20ms/step - loss: 51.5867 - reconstruction_loss: 48.3205 - kl_loss: 3.1340 - val_loss: 50.7282 - val_reconstruction_loss: 47.6436 - val_kl_loss: 3.0847
# Epoch 15/500
# 79/79 [==============================] - 2s 20ms/step - loss: 51.4011 - reconstruction_loss: 48.2287 - kl_loss: 3.0387 - val_loss: 50.5237 - val_reconstruction_loss: 47.5336 - val_kl_loss: 2.9901
# Epoch 16/500
# 79/79 [==============================] - 2s 20ms/step - loss: 51.2008 - reconstruction_loss: 48.1306 - kl_loss: 2.9454 - val_loss: 50.3530 - val_reconstruction_loss: 47.4542 - val_kl_loss: 2.8988
# Epoch 17/500
# 79/79 [==============================] - 2s 20ms/step - loss: 51.0096 - reconstruction_loss: 48.0308 - kl_loss: 2.8535 - val_loss: 50.1542 - val_reconstruction_loss: 47.3471 - val_kl_loss: 2.8071
# Epoch 18/500
# 79/79 [==============================] - 2s 20ms/step - loss: 50.8127 - reconstruction_loss: 47.9203 - kl_loss: 2.7631 - val_loss: 49.9741 - val_reconstruction_loss: 47.2551 - val_kl_loss: 2.7190
# Epoch 19/500
# 79/79 [==============================] - 2s 20ms/step - loss: 50.6299 - reconstruction_loss: 47.8251 - kl_loss: 2.6757 - val_loss: 49.7883 - val_reconstruction_loss: 47.1558 - val_kl_loss: 2.6325
# Epoch 20/500
# 79/79 [==============================] - 1s 19ms/step - loss: 50.4262 - reconstruction_loss: 47.7148 - kl_loss: 2.5900 - val_loss: 49.5777 - val_reconstruction_loss: 47.0294 - val_kl_loss: 2.5482
# Epoch 21/500
# 79/79 [==============================] - 2s 19ms/step - loss: 50.2404 - reconstruction_loss: 47.6170 - kl_loss: 2.5071 - val_loss: 49.3972 - val_reconstruction_loss: 46.9305 - val_kl_loss: 2.4667
# Epoch 22/500
# 79/79 [==============================] - 1s 19ms/step - loss: 50.0515 - reconstruction_loss: 47.5070 - kl_loss: 2.4266 - val_loss: 49.2059 - val_reconstruction_loss: 46.8185 - val_kl_loss: 2.3875
# Epoch 23/500
# 79/79 [==============================] - 2s 20ms/step - loss: 49.8791 - reconstruction_loss: 47.4094 - kl_loss: 2.3477 - val_loss: 49.0382 - val_reconstruction_loss: 46.7282 - val_kl_loss: 2.3100
# Epoch 24/500
# 79/79 [==============================] - 1s 19ms/step - loss: 49.6932 - reconstruction_loss: 47.3038 - kl_loss: 2.2711 - val_loss: 48.8646 - val_reconstruction_loss: 46.6301 - val_kl_loss: 2.2345
# Epoch 25/500
# 79/79 [==============================] - 1s 19ms/step - loss: 49.5387 - reconstruction_loss: 47.2200 - kl_loss: 2.1965 - val_loss: 48.6967 - val_reconstruction_loss: 46.5353 - val_kl_loss: 2.1613
# Epoch 26/500
# 79/79 [==============================] - 1s 19ms/step - loss: 49.3393 - reconstruction_loss: 47.0941 - kl_loss: 2.1239 - val_loss: 48.5078 - val_reconstruction_loss: 46.4186 - val_kl_loss: 2.0892
# Epoch 27/500
# 79/79 [==============================] - 2s 19ms/step - loss: 49.1771 - reconstruction_loss: 46.9971 - kl_loss: 2.0522 - val_loss: 48.3566 - val_reconstruction_loss: 46.3375 - val_kl_loss: 2.0191
# Epoch 28/500
# 79/79 [==============================] - 1s 18ms/step - loss: 49.0029 - reconstruction_loss: 46.9018 - kl_loss: 1.9836 - val_loss: 48.1840 - val_reconstruction_loss: 46.2325 - val_kl_loss: 1.9515
# Epoch 29/500
# 79/79 [==============================] - 1s 18ms/step - loss: 48.8440 - reconstruction_loss: 46.8068 - kl_loss: 1.9170 - val_loss: 48.0335 - val_reconstruction_loss: 46.1469 - val_kl_loss: 1.8866
# Epoch 30/500
# 79/79 [==============================] - 1s 19ms/step - loss: 48.6821 - reconstruction_loss: 46.7032 - kl_loss: 1.8526 - val_loss: 47.8819 - val_reconstruction_loss: 46.0589 - val_kl_loss: 1.8230
# Epoch 31/500
# 79/79 [==============================] - 1s 18ms/step - loss: 48.5019 - reconstruction_loss: 46.5900 - kl_loss: 1.7902 - val_loss: 47.7166 - val_reconstruction_loss: 45.9549 - val_kl_loss: 1.7617
# Epoch 32/500
# 79/79 [==============================] - 1s 19ms/step - loss: 48.3428 - reconstruction_loss: 46.4892 - kl_loss: 1.7300 - val_loss: 47.5645 - val_reconstruction_loss: 45.8615 - val_kl_loss: 1.7030
# Epoch 33/500
# 79/79 [==============================] - 2s 21ms/step - loss: 48.1934 - reconstruction_loss: 46.4040 - kl_loss: 1.6718 - val_loss: 47.3679 - val_reconstruction_loss: 45.7221 - val_kl_loss: 1.6458
# Epoch 34/500
# 79/79 [==============================] - 2s 21ms/step - loss: 48.0306 - reconstruction_loss: 46.3011 - kl_loss: 1.6154 - val_loss: 47.2244 - val_reconstruction_loss: 45.6342 - val_kl_loss: 1.5903
# Epoch 35/500
# 79/79 [==============================] - 1s 18ms/step - loss: 47.8614 - reconstruction_loss: 46.1942 - kl_loss: 1.5607 - val_loss: 47.0687 - val_reconstruction_loss: 45.5319 - val_kl_loss: 1.5368
# Epoch 36/500
# 79/79 [==============================] - 1s 18ms/step - loss: 47.7435 - reconstruction_loss: 46.1048 - kl_loss: 1.5083 - val_loss: 46.9472 - val_reconstruction_loss: 45.4616 - val_kl_loss: 1.4856
# Epoch 37/500
# 79/79 [==============================] - 2s 20ms/step - loss: 47.5670 - reconstruction_loss: 45.9885 - kl_loss: 1.4576 - val_loss: 46.7826 - val_reconstruction_loss: 45.3468 - val_kl_loss: 1.4357
# Epoch 38/500
# 79/79 [==============================] - 2s 19ms/step - loss: 47.4114 - reconstruction_loss: 45.8870 - kl_loss: 1.4087 - val_loss: 46.6404 - val_reconstruction_loss: 45.2526 - val_kl_loss: 1.3878
# Epoch 39/500
# 79/79 [==============================] - 2s 20ms/step - loss: 47.2646 - reconstruction_loss: 45.7893 - kl_loss: 1.3614 - val_loss: 46.5037 - val_reconstruction_loss: 45.1624 - val_kl_loss: 1.3413
# Epoch 40/500
# 79/79 [==============================] - 2s 20ms/step - loss: 47.1318 - reconstruction_loss: 45.7004 - kl_loss: 1.3157 - val_loss: 46.3244 - val_reconstruction_loss: 45.0279 - val_kl_loss: 1.2964
# Epoch 41/500
# 79/79 [==============================] - 2s 20ms/step - loss: 46.9821 - reconstruction_loss: 45.5930 - kl_loss: 1.2719 - val_loss: 46.1639 - val_reconstruction_loss: 44.9105 - val_kl_loss: 1.2534
# Epoch 42/500
# 79/79 [==============================] - 2s 20ms/step - loss: 46.8378 - reconstruction_loss: 45.4871 - kl_loss: 1.2300 - val_loss: 46.0301 - val_reconstruction_loss: 44.8176 - val_kl_loss: 1.2125
# Epoch 43/500
# 79/79 [==============================] - 2s 21ms/step - loss: 46.6650 - reconstruction_loss: 45.3748 - kl_loss: 1.1898 - val_loss: 45.9119 - val_reconstruction_loss: 44.7386 - val_kl_loss: 1.1732
# Epoch 44/500
# 79/79 [==============================] - 2s 20ms/step - loss: 46.5479 - reconstruction_loss: 45.2843 - kl_loss: 1.1515 - val_loss: 45.7663 - val_reconstruction_loss: 44.6308 - val_kl_loss: 1.1356
# Epoch 45/500
# 79/79 [==============================] - 2s 19ms/step - loss: 46.3995 - reconstruction_loss: 45.1807 - kl_loss: 1.1146 - val_loss: 45.6225 - val_reconstruction_loss: 44.5230 - val_kl_loss: 1.0995
# Epoch 46/500
# 79/79 [==============================] - 1s 19ms/step - loss: 46.2750 - reconstruction_loss: 45.0844 - kl_loss: 1.0794 - val_loss: 45.5020 - val_reconstruction_loss: 44.4369 - val_kl_loss: 1.0651
# Epoch 47/500
# 79/79 [==============================] - 1s 18ms/step - loss: 46.1371 - reconstruction_loss: 44.9789 - kl_loss: 1.0459 - val_loss: 45.3714 - val_reconstruction_loss: 44.3392 - val_kl_loss: 1.0322
# Epoch 48/500
# 79/79 [==============================] - 1s 18ms/step - loss: 46.0112 - reconstruction_loss: 44.8811 - kl_loss: 1.0137 - val_loss: 45.2277 - val_reconstruction_loss: 44.2269 - val_kl_loss: 1.0008
# Epoch 49/500
# 79/79 [==============================] - 2s 20ms/step - loss: 45.8759 - reconstruction_loss: 44.7771 - kl_loss: 0.9831 - val_loss: 45.1292 - val_reconstruction_loss: 44.1585 - val_kl_loss: 0.9707
# Epoch 50/500
# 79/79 [==============================] - 1s 19ms/step - loss: 45.7450 - reconstruction_loss: 44.6775 - kl_loss: 0.9537 - val_loss: 44.9970 - val_reconstruction_loss: 44.0552 - val_kl_loss: 0.9417
# Epoch 51/500
# 79/79 [==============================] - 2s 20ms/step - loss: 45.6206 - reconstruction_loss: 44.5705 - kl_loss: 0.9255 - val_loss: 44.8562 - val_reconstruction_loss: 43.9422 - val_kl_loss: 0.9140
# Epoch 52/500
# 79/79 [==============================] - 2s 22ms/step - loss: 45.4758 - reconstruction_loss: 44.4694 - kl_loss: 0.8986 - val_loss: 44.7229 - val_reconstruction_loss: 43.8350 - val_kl_loss: 0.8879
# Epoch 53/500
# 79/79 [==============================] - 2s 20ms/step - loss: 45.3705 - reconstruction_loss: 44.3825 - kl_loss: 0.8727 - val_loss: 44.6109 - val_reconstruction_loss: 43.7486 - val_kl_loss: 0.8624
# Epoch 54/500
# 79/79 [==============================] - 1s 19ms/step - loss: 45.2253 - reconstruction_loss: 44.2755 - kl_loss: 0.8480 - val_loss: 44.4760 - val_reconstruction_loss: 43.6380 - val_kl_loss: 0.8381
# Epoch 55/500
# 79/79 [==============================] - 2s 19ms/step - loss: 45.1198 - reconstruction_loss: 44.1834 - kl_loss: 0.8243 - val_loss: 44.3486 - val_reconstruction_loss: 43.5337 - val_kl_loss: 0.8149
# Epoch 56/500
# 79/79 [==============================] - 1s 19ms/step - loss: 44.9820 - reconstruction_loss: 44.0725 - kl_loss: 0.8019 - val_loss: 44.2321 - val_reconstruction_loss: 43.4391 - val_kl_loss: 0.7930
# Epoch 57/500
# 79/79 [==============================] - 1s 19ms/step - loss: 44.8749 - reconstruction_loss: 43.9818 - kl_loss: 0.7802 - val_loss: 44.1217 - val_reconstruction_loss: 43.3501 - val_kl_loss: 0.7716
# Epoch 58/500
# 79/79 [==============================] - 2s 20ms/step - loss: 44.7446 - reconstruction_loss: 43.8818 - kl_loss: 0.7593 - val_loss: 43.9710 - val_reconstruction_loss: 43.2201 - val_kl_loss: 0.7510
# Epoch 59/500
# 79/79 [==============================] - 1s 19ms/step - loss: 44.6194 - reconstruction_loss: 43.7730 - kl_loss: 0.7393 - val_loss: 43.8879 - val_reconstruction_loss: 43.1566 - val_kl_loss: 0.7312
# Epoch 60/500
# 79/79 [==============================] - 2s 20ms/step - loss: 44.5138 - reconstruction_loss: 43.6850 - kl_loss: 0.7201 - val_loss: 43.7533 - val_reconstruction_loss: 43.0410 - val_kl_loss: 0.7123
# Epoch 61/500
# 79/79 [==============================] - 2s 19ms/step - loss: 44.3894 - reconstruction_loss: 43.5890 - kl_loss: 0.7016 - val_loss: 43.6424 - val_reconstruction_loss: 42.9483 - val_kl_loss: 0.6942
# Epoch 62/500
# 79/79 [==============================] - 2s 19ms/step - loss: 44.2645 - reconstruction_loss: 43.4781 - kl_loss: 0.6841 - val_loss: 43.5206 - val_reconstruction_loss: 42.8437 - val_kl_loss: 0.6769
# Epoch 63/500
# 79/79 [==============================] - 1s 19ms/step - loss: 44.1577 - reconstruction_loss: 43.3841 - kl_loss: 0.6671 - val_loss: 43.4160 - val_reconstruction_loss: 42.7561 - val_kl_loss: 0.6599
# Epoch 64/500
# 79/79 [==============================] - 2s 20ms/step - loss: 44.0335 - reconstruction_loss: 43.2790 - kl_loss: 0.6506 - val_loss: 43.2971 - val_reconstruction_loss: 42.6532 - val_kl_loss: 0.6439
# Epoch 65/500
# 79/79 [==============================] - 1s 19ms/step - loss: 43.9251 - reconstruction_loss: 43.1900 - kl_loss: 0.6349 - val_loss: 43.1938 - val_reconstruction_loss: 42.5655 - val_kl_loss: 0.6283
# Epoch 66/500
# 79/79 [==============================] - 2s 20ms/step - loss: 43.7995 - reconstruction_loss: 43.0828 - kl_loss: 0.6195 - val_loss: 43.0769 - val_reconstruction_loss: 42.4638 - val_kl_loss: 0.6131
# Epoch 67/500
# 79/79 [==============================] - 2s 20ms/step - loss: 43.6981 - reconstruction_loss: 42.9884 - kl_loss: 0.6048 - val_loss: 42.9468 - val_reconstruction_loss: 42.3481 - val_kl_loss: 0.5987
# Epoch 68/500
# 79/79 [==============================] - 2s 20ms/step - loss: 43.5647 - reconstruction_loss: 42.8817 - kl_loss: 0.5906 - val_loss: 42.8435 - val_reconstruction_loss: 42.2588 - val_kl_loss: 0.5847
# Epoch 69/500
# 79/79 [==============================] - 2s 21ms/step - loss: 43.4736 - reconstruction_loss: 42.7940 - kl_loss: 0.5769 - val_loss: 42.7478 - val_reconstruction_loss: 42.1766 - val_kl_loss: 0.5713
# Epoch 70/500
# 79/79 [==============================] - 2s 21ms/step - loss: 43.3550 - reconstruction_loss: 42.6860 - kl_loss: 0.5638 - val_loss: 42.6189 - val_reconstruction_loss: 42.0606 - val_kl_loss: 0.5583
# Epoch 71/500
# 79/79 [==============================] - 1s 19ms/step - loss: 43.2227 - reconstruction_loss: 42.5753 - kl_loss: 0.5511 - val_loss: 42.5316 - val_reconstruction_loss: 41.9859 - val_kl_loss: 0.5457
# Epoch 72/500
# 79/79 [==============================] - 2s 19ms/step - loss: 43.1303 - reconstruction_loss: 42.4995 - kl_loss: 0.5387 - val_loss: 42.3994 - val_reconstruction_loss: 41.8658 - val_kl_loss: 0.5335
# Epoch 73/500
# 79/79 [==============================] - 1s 19ms/step - loss: 43.0358 - reconstruction_loss: 42.3959 - kl_loss: 0.5268 - val_loss: 42.3105 - val_reconstruction_loss: 41.7891 - val_kl_loss: 0.5215
# Epoch 74/500
# 79/79 [==============================] - 1s 18ms/step - loss: 42.9145 - reconstruction_loss: 42.2957 - kl_loss: 0.5149 - val_loss: 42.1897 - val_reconstruction_loss: 41.6799 - val_kl_loss: 0.5098
# Epoch 75/500
# 79/79 [==============================] - 2s 20ms/step - loss: 42.8068 - reconstruction_loss: 42.2014 - kl_loss: 0.5037 - val_loss: 42.0939 - val_reconstruction_loss: 41.5949 - val_kl_loss: 0.4989
# Epoch 76/500
# 79/79 [==============================] - 1s 19ms/step - loss: 42.6948 - reconstruction_loss: 42.0947 - kl_loss: 0.4928 - val_loss: 41.9864 - val_reconstruction_loss: 41.4983 - val_kl_loss: 0.4882
# Epoch 77/500
# 79/79 [==============================] - 1s 19ms/step - loss: 42.5872 - reconstruction_loss: 42.0080 - kl_loss: 0.4822 - val_loss: 41.8854 - val_reconstruction_loss: 41.4080 - val_kl_loss: 0.4774
# Epoch 78/500
# 79/79 [==============================] - 2s 20ms/step - loss: 42.4751 - reconstruction_loss: 41.9041 - kl_loss: 0.4717 - val_loss: 41.7614 - val_reconstruction_loss: 41.2942 - val_kl_loss: 0.4672
# Epoch 79/500
# 79/79 [==============================] - 2s 21ms/step - loss: 42.3729 - reconstruction_loss: 41.8098 - kl_loss: 0.4617 - val_loss: 41.6561 - val_reconstruction_loss: 41.1988 - val_kl_loss: 0.4573
# Epoch 80/500
# 79/79 [==============================] - 2s 20ms/step - loss: 42.2717 - reconstruction_loss: 41.7181 - kl_loss: 0.4520 - val_loss: 41.5614 - val_reconstruction_loss: 41.1137 - val_kl_loss: 0.4477
# Epoch 81/500
# 79/79 [==============================] - 2s 20ms/step - loss: 42.1707 - reconstruction_loss: 41.6235 - kl_loss: 0.4425 - val_loss: 41.4375 - val_reconstruction_loss: 40.9992 - val_kl_loss: 0.4383
# Epoch 82/500
# 79/79 [==============================] - 2s 20ms/step - loss: 42.0557 - reconstruction_loss: 41.5264 - kl_loss: 0.4332 - val_loss: 41.3502 - val_reconstruction_loss: 40.9211 - val_kl_loss: 0.4291
# Epoch 83/500
# 79/79 [==============================] - 2s 20ms/step - loss: 41.9402 - reconstruction_loss: 41.4178 - kl_loss: 0.4240 - val_loss: 41.2511 - val_reconstruction_loss: 40.8311 - val_kl_loss: 0.4200
# Epoch 84/500
# 79/79 [==============================] - 1s 18ms/step - loss: 41.8516 - reconstruction_loss: 41.3344 - kl_loss: 0.4151 - val_loss: 41.1246 - val_reconstruction_loss: 40.7136 - val_kl_loss: 0.4111
# Epoch 85/500
# 79/79 [==============================] - 2s 20ms/step - loss: 41.7316 - reconstruction_loss: 41.2287 - kl_loss: 0.4063 - val_loss: 41.0383 - val_reconstruction_loss: 40.6359 - val_kl_loss: 0.4024
# Epoch 86/500
# 79/79 [==============================] - 2s 21ms/step - loss: 41.6259 - reconstruction_loss: 41.1307 - kl_loss: 0.3979 - val_loss: 40.9367 - val_reconstruction_loss: 40.5427 - val_kl_loss: 0.3940
# Epoch 87/500
# 79/79 [==============================] - 2s 20ms/step - loss: 41.5329 - reconstruction_loss: 41.0510 - kl_loss: 0.3895 - val_loss: 40.8115 - val_reconstruction_loss: 40.4258 - val_kl_loss: 0.3857
# Epoch 88/500
# 79/79 [==============================] - 2s 21ms/step - loss: 41.4257 - reconstruction_loss: 40.9490 - kl_loss: 0.3813 - val_loss: 40.7367 - val_reconstruction_loss: 40.3592 - val_kl_loss: 0.3775
# Epoch 89/500
# 79/79 [==============================] - 2s 20ms/step - loss: 41.3270 - reconstruction_loss: 40.8588 - kl_loss: 0.3731 - val_loss: 40.6286 - val_reconstruction_loss: 40.2591 - val_kl_loss: 0.3694
# Epoch 90/500
# 79/79 [==============================] - 2s 21ms/step - loss: 41.2170 - reconstruction_loss: 40.7542 - kl_loss: 0.3653 - val_loss: 40.5163 - val_reconstruction_loss: 40.1547 - val_kl_loss: 0.3616
# Epoch 91/500
# 79/79 [==============================] - 1s 19ms/step - loss: 41.1109 - reconstruction_loss: 40.6567 - kl_loss: 0.3575 - val_loss: 40.4431 - val_reconstruction_loss: 40.0892 - val_kl_loss: 0.3539
# Epoch 92/500
# 79/79 [==============================] - 2s 20ms/step - loss: 41.0129 - reconstruction_loss: 40.5632 - kl_loss: 0.3499 - val_loss: 40.3113 - val_reconstruction_loss: 39.9649 - val_kl_loss: 0.3463
# Epoch 93/500
# 79/79 [==============================] - 1s 19ms/step - loss: 40.8868 - reconstruction_loss: 40.4586 - kl_loss: 0.3424 - val_loss: 40.2109 - val_reconstruction_loss: 39.8719 - val_kl_loss: 0.3389
# Epoch 94/500
# 79/79 [==============================] - 2s 21ms/step - loss: 40.8105 - reconstruction_loss: 40.3753 - kl_loss: 0.3350 - val_loss: 40.0940 - val_reconstruction_loss: 39.7625 - val_kl_loss: 0.3316
# Epoch 95/500
# 79/79 [==============================] - 2s 20ms/step - loss: 40.7125 - reconstruction_loss: 40.2774 - kl_loss: 0.3278 - val_loss: 39.9874 - val_reconstruction_loss: 39.6630 - val_kl_loss: 0.3244
# Epoch 96/500
# 79/79 [==============================] - 2s 20ms/step - loss: 40.6132 - reconstruction_loss: 40.1905 - kl_loss: 0.3208 - val_loss: 39.9064 - val_reconstruction_loss: 39.5890 - val_kl_loss: 0.3174
# Epoch 97/500
# 79/79 [==============================] - 2s 20ms/step - loss: 40.5019 - reconstruction_loss: 40.0869 - kl_loss: 0.3138 - val_loss: 39.8172 - val_reconstruction_loss: 39.5066 - val_kl_loss: 0.3106
# Epoch 98/500
# 79/79 [==============================] - 2s 20ms/step - loss: 40.3952 - reconstruction_loss: 39.9956 - kl_loss: 0.3071 - val_loss: 39.7201 - val_reconstruction_loss: 39.4163 - val_kl_loss: 0.3038
# Epoch 99/500
# 79/79 [==============================] - 2s 20ms/step - loss: 40.2971 - reconstruction_loss: 39.8939 - kl_loss: 0.3003 - val_loss: 39.6094 - val_reconstruction_loss: 39.3122 - val_kl_loss: 0.2972
# Epoch 100/500
# 79/79 [==============================] - 2s 20ms/step - loss: 40.1978 - reconstruction_loss: 39.8127 - kl_loss: 0.2937 - val_loss: 39.5233 - val_reconstruction_loss: 39.2328 - val_kl_loss: 0.2905
# Epoch 101/500
# 79/79 [==============================] - 2s 20ms/step - loss: 40.0928 - reconstruction_loss: 39.7091 - kl_loss: 0.2872 - val_loss: 39.3866 - val_reconstruction_loss: 39.1025 - val_kl_loss: 0.2841
# Epoch 102/500
# 79/79 [==============================] - 2s 20ms/step - loss: 39.9983 - reconstruction_loss: 39.6172 - kl_loss: 0.2807 - val_loss: 39.3081 - val_reconstruction_loss: 39.0305 - val_kl_loss: 0.2776
# Epoch 103/500
# 79/79 [==============================] - 2s 20ms/step - loss: 39.8876 - reconstruction_loss: 39.5237 - kl_loss: 0.2744 - val_loss: 39.2037 - val_reconstruction_loss: 38.9323 - val_kl_loss: 0.2714
# Epoch 104/500
# 79/79 [==============================] - 1s 19ms/step - loss: 39.7854 - reconstruction_loss: 39.4254 - kl_loss: 0.2682 - val_loss: 39.1272 - val_reconstruction_loss: 38.8621 - val_kl_loss: 0.2652
# Epoch 105/500
# 79/79 [==============================] - 2s 21ms/step - loss: 39.7045 - reconstruction_loss: 39.3405 - kl_loss: 0.2621 - val_loss: 39.0169 - val_reconstruction_loss: 38.7578 - val_kl_loss: 0.2591
# Epoch 106/500
# 79/79 [==============================] - 2s 20ms/step - loss: 39.5746 - reconstruction_loss: 39.2326 - kl_loss: 0.2561 - val_loss: 38.9209 - val_reconstruction_loss: 38.6678 - val_kl_loss: 0.2531
# Epoch 107/500
# 79/79 [==============================] - 2s 19ms/step - loss: 39.5056 - reconstruction_loss: 39.1524 - kl_loss: 0.2502 - val_loss: 38.8087 - val_reconstruction_loss: 38.5615 - val_kl_loss: 0.2472
# Epoch 108/500
# 79/79 [==============================] - 2s 20ms/step - loss: 39.4076 - reconstruction_loss: 39.0676 - kl_loss: 0.2443 - val_loss: 38.7342 - val_reconstruction_loss: 38.4928 - val_kl_loss: 0.2414
# Epoch 109/500
# 79/79 [==============================] - 2s 20ms/step - loss: 39.3046 - reconstruction_loss: 38.9670 - kl_loss: 0.2385 - val_loss: 38.6389 - val_reconstruction_loss: 38.4033 - val_kl_loss: 0.2356
# Epoch 110/500
# 79/79 [==============================] - 1s 19ms/step - loss: 39.1917 - reconstruction_loss: 38.8680 - kl_loss: 0.2329 - val_loss: 38.5209 - val_reconstruction_loss: 38.2908 - val_kl_loss: 0.2301
# Epoch 111/500
# 79/79 [==============================] - 1s 19ms/step - loss: 39.0963 - reconstruction_loss: 38.7799 - kl_loss: 0.2274 - val_loss: 38.4343 - val_reconstruction_loss: 38.2097 - val_kl_loss: 0.2246
# Epoch 112/500
# 79/79 [==============================] - 2s 22ms/step - loss: 39.0189 - reconstruction_loss: 38.6886 - kl_loss: 0.2221 - val_loss: 38.3309 - val_reconstruction_loss: 38.1116 - val_kl_loss: 0.2193
# Epoch 113/500
# 79/79 [==============================] - 2s 20ms/step - loss: 38.8925 - reconstruction_loss: 38.5859 - kl_loss: 0.2168 - val_loss: 38.2451 - val_reconstruction_loss: 38.0310 - val_kl_loss: 0.2141
# Epoch 114/500
# 79/79 [==============================] - 2s 20ms/step - loss: 38.8098 - reconstruction_loss: 38.5058 - kl_loss: 0.2117 - val_loss: 38.1593 - val_reconstruction_loss: 37.9502 - val_kl_loss: 0.2091
# Epoch 115/500
# 79/79 [==============================] - 2s 21ms/step - loss: 38.7188 - reconstruction_loss: 38.4206 - kl_loss: 0.2067 - val_loss: 38.0332 - val_reconstruction_loss: 37.8292 - val_kl_loss: 0.2040
# Epoch 116/500
# 79/79 [==============================] - 2s 19ms/step - loss: 38.6126 - reconstruction_loss: 38.3192 - kl_loss: 0.2017 - val_loss: 37.9722 - val_reconstruction_loss: 37.7730 - val_kl_loss: 0.1991
# Epoch 117/500
# 79/79 [==============================] - 2s 20ms/step - loss: 38.5094 - reconstruction_loss: 38.2220 - kl_loss: 0.1969 - val_loss: 37.8527 - val_reconstruction_loss: 37.6584 - val_kl_loss: 0.1944
# Epoch 118/500
# 79/79 [==============================] - 2s 22ms/step - loss: 38.4168 - reconstruction_loss: 38.1308 - kl_loss: 0.1922 - val_loss: 37.7778 - val_reconstruction_loss: 37.5880 - val_kl_loss: 0.1897
# Epoch 119/500
# 79/79 [==============================] - 2s 20ms/step - loss: 38.3163 - reconstruction_loss: 38.0339 - kl_loss: 0.1875 - val_loss: 37.6706 - val_reconstruction_loss: 37.4855 - val_kl_loss: 0.1851
# Epoch 120/500
# 79/79 [==============================] - 2s 20ms/step - loss: 38.2319 - reconstruction_loss: 37.9564 - kl_loss: 0.1829 - val_loss: 37.5816 - val_reconstruction_loss: 37.4010 - val_kl_loss: 0.1806
# Epoch 121/500
# 79/79 [==============================] - 2s 20ms/step - loss: 38.1258 - reconstruction_loss: 37.8539 - kl_loss: 0.1785 - val_loss: 37.4926 - val_reconstruction_loss: 37.3163 - val_kl_loss: 0.1763
# Epoch 122/500
# 79/79 [==============================] - 1s 19ms/step - loss: 38.0202 - reconstruction_loss: 37.7610 - kl_loss: 0.1743 - val_loss: 37.3869 - val_reconstruction_loss: 37.2148 - val_kl_loss: 0.1721
# Epoch 123/500
# 79/79 [==============================] - 2s 19ms/step - loss: 37.9379 - reconstruction_loss: 37.6698 - kl_loss: 0.1702 - val_loss: 37.2640 - val_reconstruction_loss: 37.0959 - val_kl_loss: 0.1681
# Epoch 124/500
# 79/79 [==============================] - 2s 19ms/step - loss: 37.8458 - reconstruction_loss: 37.5912 - kl_loss: 0.1661 - val_loss: 37.1962 - val_reconstruction_loss: 37.0321 - val_kl_loss: 0.1641
# Epoch 125/500
# 79/79 [==============================] - 2s 20ms/step - loss: 37.7535 - reconstruction_loss: 37.4932 - kl_loss: 0.1622 - val_loss: 37.0953 - val_reconstruction_loss: 36.9351 - val_kl_loss: 0.1602
# Epoch 126/500
# 79/79 [==============================] - 2s 21ms/step - loss: 37.6427 - reconstruction_loss: 37.3920 - kl_loss: 0.1583 - val_loss: 37.0316 - val_reconstruction_loss: 36.8752 - val_kl_loss: 0.1564
# Epoch 127/500
# 79/79 [==============================] - 2s 20ms/step - loss: 37.5388 - reconstruction_loss: 37.3009 - kl_loss: 0.1545 - val_loss: 36.9013 - val_reconstruction_loss: 36.7487 - val_kl_loss: 0.1526
# Epoch 128/500
# 79/79 [==============================] - 2s 20ms/step - loss: 37.4650 - reconstruction_loss: 37.2236 - kl_loss: 0.1508 - val_loss: 36.8224 - val_reconstruction_loss: 36.6735 - val_kl_loss: 0.1489
# Epoch 129/500
# 79/79 [==============================] - 2s 19ms/step - loss: 37.3766 - reconstruction_loss: 37.1391 - kl_loss: 0.1471 - val_loss: 36.7411 - val_reconstruction_loss: 36.5958 - val_kl_loss: 0.1453
# Epoch 130/500
# 79/79 [==============================] - 2s 19ms/step - loss: 37.2744 - reconstruction_loss: 37.0462 - kl_loss: 0.1435 - val_loss: 36.6474 - val_reconstruction_loss: 36.5056 - val_kl_loss: 0.1418
# Epoch 131/500
# 79/79 [==============================] - 2s 23ms/step - loss: 37.1774 - reconstruction_loss: 36.9532 - kl_loss: 0.1401 - val_loss: 36.5535 - val_reconstruction_loss: 36.4152 - val_kl_loss: 0.1383
# Epoch 132/500
# 79/79 [==============================] - 2s 24ms/step - loss: 37.1002 - reconstruction_loss: 36.8707 - kl_loss: 0.1365 - val_loss: 36.4429 - val_reconstruction_loss: 36.3080 - val_kl_loss: 0.1348
# Epoch 133/500
# 79/79 [==============================] - 2s 23ms/step - loss: 36.9965 - reconstruction_loss: 36.7727 - kl_loss: 0.1332 - val_loss: 36.3544 - val_reconstruction_loss: 36.2228 - val_kl_loss: 0.1315
# Epoch 134/500
# 79/79 [==============================] - 2s 27ms/step - loss: 36.9158 - reconstruction_loss: 36.6876 - kl_loss: 0.1300 - val_loss: 36.2723 - val_reconstruction_loss: 36.1440 - val_kl_loss: 0.1284
# Epoch 135/500
# 79/79 [==============================] - 2s 20ms/step - loss: 36.8173 - reconstruction_loss: 36.6015 - kl_loss: 0.1269 - val_loss: 36.1594 - val_reconstruction_loss: 36.0341 - val_kl_loss: 0.1253
# Epoch 136/500
# 79/79 [==============================] - 2s 20ms/step - loss: 36.7263 - reconstruction_loss: 36.5153 - kl_loss: 0.1238 - val_loss: 36.1043 - val_reconstruction_loss: 35.9820 - val_kl_loss: 0.1223
# Epoch 137/500
# 79/79 [==============================] - 2s 19ms/step - loss: 36.6352 - reconstruction_loss: 36.4232 - kl_loss: 0.1208 - val_loss: 35.9860 - val_reconstruction_loss: 35.8667 - val_kl_loss: 0.1193
# Epoch 138/500
# 79/79 [==============================] - 2s 21ms/step - loss: 36.5336 - reconstruction_loss: 36.3283 - kl_loss: 0.1179 - val_loss: 35.9125 - val_reconstruction_loss: 35.7960 - val_kl_loss: 0.1165
# Epoch 139/500
# 79/79 [==============================] - 2s 21ms/step - loss: 36.4475 - reconstruction_loss: 36.2441 - kl_loss: 0.1151 - val_loss: 35.8056 - val_reconstruction_loss: 35.6919 - val_kl_loss: 0.1137
# Epoch 140/500
# 79/79 [==============================] - 2s 20ms/step - loss: 36.3516 - reconstruction_loss: 36.1497 - kl_loss: 0.1123 - val_loss: 35.7263 - val_reconstruction_loss: 35.6153 - val_kl_loss: 0.1110
# Epoch 141/500
# 79/79 [==============================] - 1s 19ms/step - loss: 36.2481 - reconstruction_loss: 36.0537 - kl_loss: 0.1097 - val_loss: 35.6258 - val_reconstruction_loss: 35.5174 - val_kl_loss: 0.1085
# Epoch 142/500
# 79/79 [==============================] - 2s 20ms/step - loss: 36.1700 - reconstruction_loss: 35.9732 - kl_loss: 0.1071 - val_loss: 35.5420 - val_reconstruction_loss: 35.4361 - val_kl_loss: 0.1059
# Epoch 143/500
# 79/79 [==============================] - 2s 21ms/step - loss: 36.0840 - reconstruction_loss: 35.8903 - kl_loss: 0.1047 - val_loss: 35.4613 - val_reconstruction_loss: 35.3577 - val_kl_loss: 0.1036
# Epoch 144/500
# 79/79 [==============================] - 2s 20ms/step - loss: 35.9955 - reconstruction_loss: 35.8013 - kl_loss: 0.1023 - val_loss: 35.3764 - val_reconstruction_loss: 35.2752 - val_kl_loss: 0.1012
# Epoch 145/500
# 79/79 [==============================] - 2s 19ms/step - loss: 35.8999 - reconstruction_loss: 35.7128 - kl_loss: 0.1000 - val_loss: 35.2715 - val_reconstruction_loss: 35.1725 - val_kl_loss: 0.0990
# Epoch 146/500
# 79/79 [==============================] - 1s 19ms/step - loss: 35.7999 - reconstruction_loss: 35.6226 - kl_loss: 0.0978 - val_loss: 35.1989 - val_reconstruction_loss: 35.1022 - val_kl_loss: 0.0968
# Epoch 147/500
# 79/79 [==============================] - 1s 19ms/step - loss: 35.7235 - reconstruction_loss: 35.5422 - kl_loss: 0.0956 - val_loss: 35.1015 - val_reconstruction_loss: 35.0069 - val_kl_loss: 0.0946
# Epoch 148/500
# 79/79 [==============================] - 2s 19ms/step - loss: 35.6315 - reconstruction_loss: 35.4449 - kl_loss: 0.0935 - val_loss: 35.0064 - val_reconstruction_loss: 34.9139 - val_kl_loss: 0.0925
# Epoch 149/500
# 79/79 [==============================] - 1s 19ms/step - loss: 35.5416 - reconstruction_loss: 35.3547 - kl_loss: 0.0913 - val_loss: 34.9389 - val_reconstruction_loss: 34.8486 - val_kl_loss: 0.0903
# Epoch 150/500
# 79/79 [==============================] - 1s 19ms/step - loss: 35.4453 - reconstruction_loss: 35.2657 - kl_loss: 0.0891 - val_loss: 34.8317 - val_reconstruction_loss: 34.7437 - val_kl_loss: 0.0880
# Epoch 151/500
# 79/79 [==============================] - 2s 20ms/step - loss: 35.3697 - reconstruction_loss: 35.1903 - kl_loss: 0.0869 - val_loss: 34.7454 - val_reconstruction_loss: 34.6595 - val_kl_loss: 0.0859
# Epoch 152/500
# 79/79 [==============================] - 1s 17ms/step - loss: 35.2669 - reconstruction_loss: 35.0930 - kl_loss: 0.0848 - val_loss: 34.6349 - val_reconstruction_loss: 34.5510 - val_kl_loss: 0.0839
# Epoch 153/500
# 79/79 [==============================] - 1s 19ms/step - loss: 35.1737 - reconstruction_loss: 35.0080 - kl_loss: 0.0828 - val_loss: 34.5668 - val_reconstruction_loss: 34.4849 - val_kl_loss: 0.0819
# Epoch 154/500
# 79/79 [==============================] - 2s 20ms/step - loss: 35.0750 - reconstruction_loss: 34.9149 - kl_loss: 0.0809 - val_loss: 34.4850 - val_reconstruction_loss: 34.4050 - val_kl_loss: 0.0801
# Epoch 155/500
# 79/79 [==============================] - 1s 18ms/step - loss: 35.0037 - reconstruction_loss: 34.8387 - kl_loss: 0.0791 - val_loss: 34.4027 - val_reconstruction_loss: 34.3244 - val_kl_loss: 0.0784
# Epoch 156/500
# 79/79 [==============================] - 1s 18ms/step - loss: 34.9114 - reconstruction_loss: 34.7540 - kl_loss: 0.0775 - val_loss: 34.2898 - val_reconstruction_loss: 34.2131 - val_kl_loss: 0.0767
# Epoch 157/500
# 79/79 [==============================] - 2s 19ms/step - loss: 34.8232 - reconstruction_loss: 34.6594 - kl_loss: 0.0758 - val_loss: 34.2073 - val_reconstruction_loss: 34.1323 - val_kl_loss: 0.0750
# Epoch 158/500
# 79/79 [==============================] - 1s 18ms/step - loss: 34.7267 - reconstruction_loss: 34.5681 - kl_loss: 0.0741 - val_loss: 34.1368 - val_reconstruction_loss: 34.0634 - val_kl_loss: 0.0733
# Epoch 159/500
# 79/79 [==============================] - 2s 20ms/step - loss: 34.6536 - reconstruction_loss: 34.4899 - kl_loss: 0.0726 - val_loss: 34.0570 - val_reconstruction_loss: 33.9851 - val_kl_loss: 0.0719
# Epoch 160/500
# 79/79 [==============================] - 1s 19ms/step - loss: 34.5667 - reconstruction_loss: 34.4043 - kl_loss: 0.0711 - val_loss: 33.9481 - val_reconstruction_loss: 33.8778 - val_kl_loss: 0.0704
# Epoch 161/500
# 79/79 [==============================] - 2s 19ms/step - loss: 34.4746 - reconstruction_loss: 34.3188 - kl_loss: 0.0696 - val_loss: 33.8650 - val_reconstruction_loss: 33.7961 - val_kl_loss: 0.0689
# Epoch 162/500
# 79/79 [==============================] - 2s 20ms/step - loss: 34.3731 - reconstruction_loss: 34.2275 - kl_loss: 0.0681 - val_loss: 33.8012 - val_reconstruction_loss: 33.7336 - val_kl_loss: 0.0676
# Epoch 163/500
# 79/79 [==============================] - 1s 19ms/step - loss: 34.2824 - reconstruction_loss: 34.1326 - kl_loss: 0.0668 - val_loss: 33.7084 - val_reconstruction_loss: 33.6422 - val_kl_loss: 0.0662
# Epoch 164/500
# 79/79 [==============================] - 2s 19ms/step - loss: 34.2041 - reconstruction_loss: 34.0512 - kl_loss: 0.0655 - val_loss: 33.6127 - val_reconstruction_loss: 33.5477 - val_kl_loss: 0.0650
# Epoch 165/500
# 79/79 [==============================] - 2s 20ms/step - loss: 34.1097 - reconstruction_loss: 33.9653 - kl_loss: 0.0642 - val_loss: 33.5260 - val_reconstruction_loss: 33.4623 - val_kl_loss: 0.0637
# Epoch 166/500
# 79/79 [==============================] - 2s 19ms/step - loss: 34.0183 - reconstruction_loss: 33.8740 - kl_loss: 0.0629 - val_loss: 33.4329 - val_reconstruction_loss: 33.3704 - val_kl_loss: 0.0625
# Epoch 167/500
# 79/79 [==============================] - 2s 19ms/step - loss: 33.9360 - reconstruction_loss: 33.7957 - kl_loss: 0.0618 - val_loss: 33.3647 - val_reconstruction_loss: 33.3033 - val_kl_loss: 0.0614
# Epoch 168/500
# 79/79 [==============================] - 1s 19ms/step - loss: 33.8492 - reconstruction_loss: 33.7068 - kl_loss: 0.0607 - val_loss: 33.2572 - val_reconstruction_loss: 33.1970 - val_kl_loss: 0.0602
# Epoch 169/500
# 79/79 [==============================] - 2s 19ms/step - loss: 33.7714 - reconstruction_loss: 33.6290 - kl_loss: 0.0596 - val_loss: 33.2028 - val_reconstruction_loss: 33.1435 - val_kl_loss: 0.0592
# Epoch 170/500
# 79/79 [==============================] - 1s 19ms/step - loss: 33.6826 - reconstruction_loss: 33.5417 - kl_loss: 0.0585 - val_loss: 33.1040 - val_reconstruction_loss: 33.0459 - val_kl_loss: 0.0581
# Epoch 171/500
# 79/79 [==============================] - 1s 19ms/step - loss: 33.6075 - reconstruction_loss: 33.4635 - kl_loss: 0.0575 - val_loss: 33.0270 - val_reconstruction_loss: 32.9699 - val_kl_loss: 0.0571
# Epoch 172/500
# 79/79 [==============================] - 2s 19ms/step - loss: 33.5148 - reconstruction_loss: 33.3751 - kl_loss: 0.0564 - val_loss: 32.9367 - val_reconstruction_loss: 32.8807 - val_kl_loss: 0.0560
# Epoch 173/500
# 79/79 [==============================] - 1s 19ms/step - loss: 33.4221 - reconstruction_loss: 33.2867 - kl_loss: 0.0554 - val_loss: 32.8453 - val_reconstruction_loss: 32.7902 - val_kl_loss: 0.0551
# Epoch 174/500
# 79/79 [==============================] - 1s 19ms/step - loss: 33.3421 - reconstruction_loss: 33.2096 - kl_loss: 0.0544 - val_loss: 32.7574 - val_reconstruction_loss: 32.7033 - val_kl_loss: 0.0541
# Epoch 175/500
# 79/79 [==============================] - 2s 20ms/step - loss: 33.2780 - reconstruction_loss: 33.1295 - kl_loss: 0.0534 - val_loss: 32.6833 - val_reconstruction_loss: 32.6301 - val_kl_loss: 0.0532
# Epoch 176/500
# 79/79 [==============================] - 1s 19ms/step - loss: 33.1739 - reconstruction_loss: 33.0457 - kl_loss: 0.0525 - val_loss: 32.6089 - val_reconstruction_loss: 32.5567 - val_kl_loss: 0.0522
# Epoch 177/500
# 79/79 [==============================] - 1s 19ms/step - loss: 33.0916 - reconstruction_loss: 32.9658 - kl_loss: 0.0515 - val_loss: 32.5187 - val_reconstruction_loss: 32.4675 - val_kl_loss: 0.0513
# Epoch 178/500
# 79/79 [==============================] - 1s 19ms/step - loss: 33.0161 - reconstruction_loss: 32.8794 - kl_loss: 0.0505 - val_loss: 32.4393 - val_reconstruction_loss: 32.3892 - val_kl_loss: 0.0501
# Epoch 179/500
# 79/79 [==============================] - 2s 20ms/step - loss: 32.9161 - reconstruction_loss: 32.7892 - kl_loss: 0.0492 - val_loss: 32.3402 - val_reconstruction_loss: 32.2916 - val_kl_loss: 0.0487
# Epoch 180/500
# 79/79 [==============================] - 2s 19ms/step - loss: 32.8404 - reconstruction_loss: 32.7118 - kl_loss: 0.0478 - val_loss: 32.2705 - val_reconstruction_loss: 32.2229 - val_kl_loss: 0.0476
# Epoch 181/500
# 79/79 [==============================] - 2s 21ms/step - loss: 32.7667 - reconstruction_loss: 32.6348 - kl_loss: 0.0468 - val_loss: 32.1856 - val_reconstruction_loss: 32.1390 - val_kl_loss: 0.0465
# Epoch 182/500
# 79/79 [==============================] - 2s 19ms/step - loss: 32.6657 - reconstruction_loss: 32.5403 - kl_loss: 0.0458 - val_loss: 32.1070 - val_reconstruction_loss: 32.0615 - val_kl_loss: 0.0456
# Epoch 183/500
# 79/79 [==============================] - 1s 19ms/step - loss: 32.5861 - reconstruction_loss: 32.4564 - kl_loss: 0.0448 - val_loss: 32.0206 - val_reconstruction_loss: 31.9760 - val_kl_loss: 0.0446
# Epoch 184/500
# 79/79 [==============================] - 1s 19ms/step - loss: 32.5024 - reconstruction_loss: 32.3814 - kl_loss: 0.0439 - val_loss: 31.9393 - val_reconstruction_loss: 31.8955 - val_kl_loss: 0.0438
# Epoch 185/500
# 79/79 [==============================] - 1s 18ms/step - loss: 32.4181 - reconstruction_loss: 32.3000 - kl_loss: 0.0431 - val_loss: 31.8753 - val_reconstruction_loss: 31.8323 - val_kl_loss: 0.0431
# Epoch 186/500
# 79/79 [==============================] - 1s 19ms/step - loss: 32.3311 - reconstruction_loss: 32.2113 - kl_loss: 0.0423 - val_loss: 31.7748 - val_reconstruction_loss: 31.7325 - val_kl_loss: 0.0422
# Epoch 187/500
# 79/79 [==============================] - 2s 20ms/step - loss: 32.2566 - reconstruction_loss: 32.1339 - kl_loss: 0.0415 - val_loss: 31.6835 - val_reconstruction_loss: 31.6420 - val_kl_loss: 0.0415
# Epoch 188/500
# 79/79 [==============================] - 2s 21ms/step - loss: 32.1724 - reconstruction_loss: 32.0542 - kl_loss: 0.0408 - val_loss: 31.6194 - val_reconstruction_loss: 31.5787 - val_kl_loss: 0.0407
# Epoch 189/500
# 79/79 [==============================] - 2s 21ms/step - loss: 32.0872 - reconstruction_loss: 31.9701 - kl_loss: 0.0401 - val_loss: 31.5282 - val_reconstruction_loss: 31.4882 - val_kl_loss: 0.0400
# Epoch 190/500
# 79/79 [==============================] - 1s 18ms/step - loss: 32.0199 - reconstruction_loss: 31.8991 - kl_loss: 0.0394 - val_loss: 31.4517 - val_reconstruction_loss: 31.4124 - val_kl_loss: 0.0394
# Epoch 191/500
# 79/79 [==============================] - 2s 20ms/step - loss: 31.9267 - reconstruction_loss: 31.8166 - kl_loss: 0.0387 - val_loss: 31.3601 - val_reconstruction_loss: 31.3215 - val_kl_loss: 0.0385
# Epoch 192/500
# 79/79 [==============================] - 2s 20ms/step - loss: 31.8477 - reconstruction_loss: 31.7377 - kl_loss: 0.0379 - val_loss: 31.2795 - val_reconstruction_loss: 31.2417 - val_kl_loss: 0.0378
# Epoch 193/500
# 79/79 [==============================] - 2s 20ms/step - loss: 31.7650 - reconstruction_loss: 31.6528 - kl_loss: 0.0372 - val_loss: 31.2167 - val_reconstruction_loss: 31.1796 - val_kl_loss: 0.0371
# Epoch 194/500
# 79/79 [==============================] - 2s 21ms/step - loss: 31.6887 - reconstruction_loss: 31.5767 - kl_loss: 0.0365 - val_loss: 31.1218 - val_reconstruction_loss: 31.0853 - val_kl_loss: 0.0365
# Epoch 195/500
# 79/79 [==============================] - 1s 19ms/step - loss: 31.6123 - reconstruction_loss: 31.4958 - kl_loss: 0.0358 - val_loss: 31.0712 - val_reconstruction_loss: 31.0354 - val_kl_loss: 0.0358
# Epoch 196/500
# 79/79 [==============================] - 2s 19ms/step - loss: 31.5387 - reconstruction_loss: 31.4142 - kl_loss: 0.0353 - val_loss: 30.9666 - val_reconstruction_loss: 30.9314 - val_kl_loss: 0.0352
# Epoch 197/500
# 79/79 [==============================] - 2s 20ms/step - loss: 31.4417 - reconstruction_loss: 31.3330 - kl_loss: 0.0345 - val_loss: 30.8963 - val_reconstruction_loss: 30.8618 - val_kl_loss: 0.0345
# Epoch 198/500
# 79/79 [==============================] - 2s 20ms/step - loss: 31.3592 - reconstruction_loss: 31.2479 - kl_loss: 0.0338 - val_loss: 30.8282 - val_reconstruction_loss: 30.7945 - val_kl_loss: 0.0337
# Epoch 199/500
# 79/79 [==============================] - 1s 19ms/step - loss: 31.2901 - reconstruction_loss: 31.1780 - kl_loss: 0.0332 - val_loss: 30.7384 - val_reconstruction_loss: 30.7053 - val_kl_loss: 0.0331
# Epoch 200/500
# 79/79 [==============================] - 1s 18ms/step - loss: 31.2107 - reconstruction_loss: 31.0977 - kl_loss: 0.0326 - val_loss: 30.6522 - val_reconstruction_loss: 30.6197 - val_kl_loss: 0.0325
# Epoch 201/500
# 79/79 [==============================] - 2s 19ms/step - loss: 31.1262 - reconstruction_loss: 31.0216 - kl_loss: 0.0319 - val_loss: 30.5764 - val_reconstruction_loss: 30.5444 - val_kl_loss: 0.0320
# Epoch 202/500
# 79/79 [==============================] - 2s 20ms/step - loss: 31.0404 - reconstruction_loss: 30.9367 - kl_loss: 0.0313 - val_loss: 30.5169 - val_reconstruction_loss: 30.4857 - val_kl_loss: 0.0312
# Epoch 203/500
# 79/79 [==============================] - 1s 19ms/step - loss: 30.9772 - reconstruction_loss: 30.8634 - kl_loss: 0.0307 - val_loss: 30.4306 - val_reconstruction_loss: 30.3999 - val_kl_loss: 0.0308
# Epoch 204/500
# 79/79 [==============================] - 2s 20ms/step - loss: 30.8924 - reconstruction_loss: 30.7903 - kl_loss: 0.0303 - val_loss: 30.3670 - val_reconstruction_loss: 30.3368 - val_kl_loss: 0.0302
# Epoch 205/500
# 79/79 [==============================] - 2s 21ms/step - loss: 30.8122 - reconstruction_loss: 30.7099 - kl_loss: 0.0297 - val_loss: 30.2649 - val_reconstruction_loss: 30.2352 - val_kl_loss: 0.0297
# Epoch 206/500
# 79/79 [==============================] - 2s 22ms/step - loss: 30.7391 - reconstruction_loss: 30.6358 - kl_loss: 0.0292 - val_loss: 30.2166 - val_reconstruction_loss: 30.1876 - val_kl_loss: 0.0291
# Epoch 207/500
# 79/79 [==============================] - 2s 20ms/step - loss: 30.6674 - reconstruction_loss: 30.5581 - kl_loss: 0.0286 - val_loss: 30.1296 - val_reconstruction_loss: 30.1010 - val_kl_loss: 0.0286
# Epoch 208/500
# 79/79 [==============================] - 2s 19ms/step - loss: 30.5765 - reconstruction_loss: 30.4788 - kl_loss: 0.0281 - val_loss: 30.0355 - val_reconstruction_loss: 30.0075 - val_kl_loss: 0.0280
# Epoch 209/500
# 79/79 [==============================] - 2s 19ms/step - loss: 30.5033 - reconstruction_loss: 30.3989 - kl_loss: 0.0275 - val_loss: 29.9709 - val_reconstruction_loss: 29.9435 - val_kl_loss: 0.0274
# Epoch 210/500
# 79/79 [==============================] - 2s 20ms/step - loss: 30.4232 - reconstruction_loss: 30.3315 - kl_loss: 0.0269 - val_loss: 29.8996 - val_reconstruction_loss: 29.8726 - val_kl_loss: 0.0269
# Epoch 211/500
# 79/79 [==============================] - 2s 19ms/step - loss: 30.3497 - reconstruction_loss: 30.2493 - kl_loss: 0.0264 - val_loss: 29.8200 - val_reconstruction_loss: 29.7936 - val_kl_loss: 0.0264
# Epoch 212/500
# 79/79 [==============================] - 1s 19ms/step - loss: 30.2724 - reconstruction_loss: 30.1726 - kl_loss: 0.0259 - val_loss: 29.7285 - val_reconstruction_loss: 29.7026 - val_kl_loss: 0.0259
# Epoch 213/500
# 79/79 [==============================] - 1s 18ms/step - loss: 30.1944 - reconstruction_loss: 30.0889 - kl_loss: 0.0254 - val_loss: 29.6682 - val_reconstruction_loss: 29.6428 - val_kl_loss: 0.0253
# Epoch 214/500
# 79/79 [==============================] - 1s 19ms/step - loss: 30.1133 - reconstruction_loss: 30.0175 - kl_loss: 0.0249 - val_loss: 29.5983 - val_reconstruction_loss: 29.5734 - val_kl_loss: 0.0249
# Epoch 215/500
# 79/79 [==============================] - 2s 19ms/step - loss: 30.0456 - reconstruction_loss: 29.9451 - kl_loss: 0.0244 - val_loss: 29.5197 - val_reconstruction_loss: 29.4953 - val_kl_loss: 0.0244
# Epoch 216/500
# 79/79 [==============================] - 1s 18ms/step - loss: 29.9660 - reconstruction_loss: 29.8710 - kl_loss: 0.0240 - val_loss: 29.4407 - val_reconstruction_loss: 29.4168 - val_kl_loss: 0.0240
# Epoch 217/500
# 79/79 [==============================] - 1s 18ms/step - loss: 29.8986 - reconstruction_loss: 29.7967 - kl_loss: 0.0236 - val_loss: 29.3681 - val_reconstruction_loss: 29.3446 - val_kl_loss: 0.0235
# Epoch 218/500
# 79/79 [==============================] - 2s 19ms/step - loss: 29.8202 - reconstruction_loss: 29.7254 - kl_loss: 0.0232 - val_loss: 29.2948 - val_reconstruction_loss: 29.2716 - val_kl_loss: 0.0232
# Epoch 219/500
# 79/79 [==============================] - 1s 18ms/step - loss: 29.7331 - reconstruction_loss: 29.6426 - kl_loss: 0.0226 - val_loss: 29.2236 - val_reconstruction_loss: 29.2011 - val_kl_loss: 0.0225
# Epoch 220/500
# 79/79 [==============================] - 1s 19ms/step - loss: 29.6629 - reconstruction_loss: 29.5664 - kl_loss: 0.0221 - val_loss: 29.1527 - val_reconstruction_loss: 29.1306 - val_kl_loss: 0.0221
# Epoch 221/500
# 79/79 [==============================] - 1s 19ms/step - loss: 29.5943 - reconstruction_loss: 29.4996 - kl_loss: 0.0216 - val_loss: 29.0623 - val_reconstruction_loss: 29.0407 - val_kl_loss: 0.0216
# Epoch 222/500
# 79/79 [==============================] - 2s 19ms/step - loss: 29.5239 - reconstruction_loss: 29.4278 - kl_loss: 0.0212 - val_loss: 29.0004 - val_reconstruction_loss: 28.9792 - val_kl_loss: 0.0212
# Epoch 223/500
# 79/79 [==============================] - 1s 18ms/step - loss: 29.4449 - reconstruction_loss: 29.3537 - kl_loss: 0.0208 - val_loss: 28.9158 - val_reconstruction_loss: 28.8949 - val_kl_loss: 0.0209
# Epoch 224/500
# 79/79 [==============================] - 1s 19ms/step - loss: 29.3636 - reconstruction_loss: 29.2705 - kl_loss: 0.0204 - val_loss: 28.8611 - val_reconstruction_loss: 28.8407 - val_kl_loss: 0.0204
# Epoch 225/500
# 79/79 [==============================] - 1s 19ms/step - loss: 29.2933 - reconstruction_loss: 29.2019 - kl_loss: 0.0200 - val_loss: 28.7874 - val_reconstruction_loss: 28.7674 - val_kl_loss: 0.0200
# Epoch 226/500
# 79/79 [==============================] - 1s 19ms/step - loss: 29.2185 - reconstruction_loss: 29.1310 - kl_loss: 0.0196 - val_loss: 28.7187 - val_reconstruction_loss: 28.6991 - val_kl_loss: 0.0196
# Epoch 227/500
# 79/79 [==============================] - 1s 18ms/step - loss: 29.1475 - reconstruction_loss: 29.0568 - kl_loss: 0.0192 - val_loss: 28.6370 - val_reconstruction_loss: 28.6178 - val_kl_loss: 0.0192
# Epoch 228/500
# 79/79 [==============================] - 1s 18ms/step - loss: 29.0775 - reconstruction_loss: 28.9893 - kl_loss: 0.0189 - val_loss: 28.5784 - val_reconstruction_loss: 28.5593 - val_kl_loss: 0.0190
# Epoch 229/500
# ...
# Epoch 426/500
# 79/79 [==============================] - 2s 20ms/step - loss: 18.0398 - reconstruction_loss: 18.0051 - kl_loss: 0.0040 - val_loss: 17.7446 - val_reconstruction_loss: 17.7406 - val_kl_loss: 0.0040
# Epoch 427/500
# 79/79 [==============================] - 2s 19ms/step - loss: 17.9933 - reconstruction_loss: 17.9558 - kl_loss: 0.0040 - val_loss: 17.7157 - val_reconstruction_loss: 17.7117 - val_kl_loss: 0.0040
# Epoch 428/500
# 79/79 [==============================] - 2s 20ms/step - loss: 17.9531 - reconstruction_loss: 17.9178 - kl_loss: 0.0040 - val_loss: 17.6750 - val_reconstruction_loss: 17.6710 - val_kl_loss: 0.0040
# Epoch 429/500
# 79/79 [==============================] - 1s 19ms/step - loss: 17.9232 - reconstruction_loss: 17.8840 - kl_loss: 0.0039 - val_loss: 17.6544 - val_reconstruction_loss: 17.6504 - val_kl_loss: 0.0039
# Epoch 430/500
# 79/79 [==============================] - 2s 20ms/step - loss: 17.8777 - reconstruction_loss: 17.8431 - kl_loss: 0.0039 - val_loss: 17.5971 - val_reconstruction_loss: 17.5932 - val_kl_loss: 0.0040
# Epoch 431/500
# 79/79 [==============================] - 2s 20ms/step - loss: 17.8309 - reconstruction_loss: 17.8051 - kl_loss: 0.0039 - val_loss: 17.5536 - val_reconstruction_loss: 17.5497 - val_kl_loss: 0.0039
# Epoch 432/500
# 79/79 [==============================] - 1s 18ms/step - loss: 17.7909 - reconstruction_loss: 17.7640 - kl_loss: 0.0039 - val_loss: 17.5216 - val_reconstruction_loss: 17.5176 - val_kl_loss: 0.0039
# Epoch 433/500
# 79/79 [==============================] - 2s 20ms/step - loss: 17.7559 - reconstruction_loss: 17.7258 - kl_loss: 0.0039 - val_loss: 17.4832 - val_reconstruction_loss: 17.4793 - val_kl_loss: 0.0039
# Epoch 434/500
# 79/79 [==============================] - 2s 20ms/step - loss: 17.7192 - reconstruction_loss: 17.6842 - kl_loss: 0.0039 - val_loss: 17.4546 - val_reconstruction_loss: 17.4506 - val_kl_loss: 0.0039
# Epoch 435/500
# 79/79 [==============================] - 2s 19ms/step - loss: 17.6703 - reconstruction_loss: 17.6389 - kl_loss: 0.0039 - val_loss: 17.3950 - val_reconstruction_loss: 17.3911 - val_kl_loss: 0.0039
# Epoch 436/500
# 79/79 [==============================] - 2s 20ms/step - loss: 17.6473 - reconstruction_loss: 17.6108 - kl_loss: 0.0039 - val_loss: 17.3538 - val_reconstruction_loss: 17.3499 - val_kl_loss: 0.0039
# Epoch 437/500
# 79/79 [==============================] - 2s 19ms/step - loss: 17.5994 - reconstruction_loss: 17.5595 - kl_loss: 0.0039 - val_loss: 17.3120 - val_reconstruction_loss: 17.3081 - val_kl_loss: 0.0039
# Epoch 438/500
# 79/79 [==============================] - 1s 18ms/step - loss: 17.5620 - reconstruction_loss: 17.5248 - kl_loss: 0.0039 - val_loss: 17.2835 - val_reconstruction_loss: 17.2796 - val_kl_loss: 0.0039
# Epoch 439/500
# 79/79 [==============================] - 2s 21ms/step - loss: 17.5137 - reconstruction_loss: 17.4886 - kl_loss: 0.0038 - val_loss: 17.2273 - val_reconstruction_loss: 17.2235 - val_kl_loss: 0.0038
# Epoch 440/500
# 79/79 [==============================] - 1s 19ms/step - loss: 17.4775 - reconstruction_loss: 17.4465 - kl_loss: 0.0038 - val_loss: 17.2139 - val_reconstruction_loss: 17.2101 - val_kl_loss: 0.0038
# Epoch 441/500
# 79/79 [==============================] - 2s 20ms/step - loss: 17.4468 - reconstruction_loss: 17.4160 - kl_loss: 0.0038 - val_loss: 17.1699 - val_reconstruction_loss: 17.1661 - val_kl_loss: 0.0038
# Epoch 442/500
# 79/79 [==============================] - 1s 19ms/step - loss: 17.4061 - reconstruction_loss: 17.3713 - kl_loss: 0.0038 - val_loss: 17.1298 - val_reconstruction_loss: 17.1260 - val_kl_loss: 0.0038
# Epoch 443/500
# 79/79 [==============================] - 2s 20ms/step - loss: 17.3692 - reconstruction_loss: 17.3383 - kl_loss: 0.0038 - val_loss: 17.0967 - val_reconstruction_loss: 17.0928 - val_kl_loss: 0.0039
# Epoch 444/500
# 79/79 [==============================] - 2s 21ms/step - loss: 17.3140 - reconstruction_loss: 17.2874 - kl_loss: 0.0038 - val_loss: 17.0487 - val_reconstruction_loss: 17.0450 - val_kl_loss: 0.0038
# Epoch 445/500
# 79/79 [==============================] - 2s 21ms/step - loss: 17.2837 - reconstruction_loss: 17.2498 - kl_loss: 0.0038 - val_loss: 17.0267 - val_reconstruction_loss: 17.0229 - val_kl_loss: 0.0038
# Epoch 446/500
# 79/79 [==============================] - 2s 22ms/step - loss: 17.2558 - reconstruction_loss: 17.2237 - kl_loss: 0.0038 - val_loss: 16.9722 - val_reconstruction_loss: 16.9683 - val_kl_loss: 0.0039
# Epoch 447/500
# 79/79 [==============================] - 2s 22ms/step - loss: 17.2021 - reconstruction_loss: 17.1803 - kl_loss: 0.0038 - val_loss: 16.9314 - val_reconstruction_loss: 16.9276 - val_kl_loss: 0.0038
# Epoch 448/500
# 79/79 [==============================] - 2s 21ms/step - loss: 17.1700 - reconstruction_loss: 17.1438 - kl_loss: 0.0038 - val_loss: 16.9063 - val_reconstruction_loss: 16.9026 - val_kl_loss: 0.0037
# Epoch 449/500
# 79/79 [==============================] - 2s 21ms/step - loss: 17.1337 - reconstruction_loss: 17.1064 - kl_loss: 0.0037 - val_loss: 16.8762 - val_reconstruction_loss: 16.8725 - val_kl_loss: 0.0038
# Epoch 450/500
# 79/79 [==============================] - 2s 20ms/step - loss: 17.1033 - reconstruction_loss: 17.0668 - kl_loss: 0.0038 - val_loss: 16.8228 - val_reconstruction_loss: 16.8190 - val_kl_loss: 0.0038
# Epoch 451/500
# 79/79 [==============================] - 2s 20ms/step - loss: 17.0426 - reconstruction_loss: 17.0227 - kl_loss: 0.0037 - val_loss: 16.8020 - val_reconstruction_loss: 16.7982 - val_kl_loss: 0.0037
# Epoch 452/500
# 79/79 [==============================] - 1s 19ms/step - loss: 17.0147 - reconstruction_loss: 16.9929 - kl_loss: 0.0038 - val_loss: 16.7570 - val_reconstruction_loss: 16.7532 - val_kl_loss: 0.0038
# Epoch 453/500
# 79/79 [==============================] - 2s 20ms/step - loss: 16.9792 - reconstruction_loss: 16.9518 - kl_loss: 0.0038 - val_loss: 16.7201 - val_reconstruction_loss: 16.7163 - val_kl_loss: 0.0038
# Epoch 454/500
# 79/79 [==============================] - 1s 19ms/step - loss: 16.9468 - reconstruction_loss: 16.9184 - kl_loss: 0.0038 - val_loss: 16.6928 - val_reconstruction_loss: 16.6891 - val_kl_loss: 0.0037
# Epoch 455/500
# 79/79 [==============================] - 2s 19ms/step - loss: 16.9102 - reconstruction_loss: 16.8826 - kl_loss: 0.0037 - val_loss: 16.6474 - val_reconstruction_loss: 16.6437 - val_kl_loss: 0.0037
# Epoch 456/500
# 79/79 [==============================] - 2s 20ms/step - loss: 16.8707 - reconstruction_loss: 16.8390 - kl_loss: 0.0037 - val_loss: 16.6175 - val_reconstruction_loss: 16.6139 - val_kl_loss: 0.0037
# Epoch 457/500
# 79/79 [==============================] - 2s 20ms/step - loss: 16.8396 - reconstruction_loss: 16.8091 - kl_loss: 0.0037 - val_loss: 16.5854 - val_reconstruction_loss: 16.5817 - val_kl_loss: 0.0037
# Epoch 458/500
# 79/79 [==============================] - 2s 20ms/step - loss: 16.8047 - reconstruction_loss: 16.7781 - kl_loss: 0.0036 - val_loss: 16.5221 - val_reconstruction_loss: 16.5185 - val_kl_loss: 0.0036
# Epoch 459/500
# 79/79 [==============================] - 2s 20ms/step - loss: 16.7634 - reconstruction_loss: 16.7315 - kl_loss: 0.0036 - val_loss: 16.5042 - val_reconstruction_loss: 16.5006 - val_kl_loss: 0.0036
# Epoch 460/500
# 79/79 [==============================] - 1s 19ms/step - loss: 16.7252 - reconstruction_loss: 16.6962 - kl_loss: 0.0036 - val_loss: 16.4756 - val_reconstruction_loss: 16.4720 - val_kl_loss: 0.0036
# Epoch 461/500
# 79/79 [==============================] - 1s 18ms/step - loss: 16.6844 - reconstruction_loss: 16.6522 - kl_loss: 0.0036 - val_loss: 16.4429 - val_reconstruction_loss: 16.4393 - val_kl_loss: 0.0036
# Epoch 462/500
# 79/79 [==============================] - 2s 22ms/step - loss: 16.6573 - reconstruction_loss: 16.6298 - kl_loss: 0.0036 - val_loss: 16.4027 - val_reconstruction_loss: 16.3991 - val_kl_loss: 0.0037
# Epoch 463/500
# 79/79 [==============================] - 2s 20ms/step - loss: 16.6124 - reconstruction_loss: 16.5892 - kl_loss: 0.0036 - val_loss: 16.3812 - val_reconstruction_loss: 16.3776 - val_kl_loss: 0.0036
# Epoch 464/500
# 79/79 [==============================] - 2s 19ms/step - loss: 16.5908 - reconstruction_loss: 16.5632 - kl_loss: 0.0036 - val_loss: 16.3240 - val_reconstruction_loss: 16.3204 - val_kl_loss: 0.0036
# Epoch 465/500
# 79/79 [==============================] - 2s 23ms/step - loss: 16.5585 - reconstruction_loss: 16.5330 - kl_loss: 0.0036 - val_loss: 16.2917 - val_reconstruction_loss: 16.2880 - val_kl_loss: 0.0037
# Epoch 466/500
# 79/79 [==============================] - 2s 28ms/step - loss: 16.5046 - reconstruction_loss: 16.4786 - kl_loss: 0.0037 - val_loss: 16.2576 - val_reconstruction_loss: 16.2539 - val_kl_loss: 0.0037
# Epoch 467/500
# 79/79 [==============================] - 2s 25ms/step - loss: 16.4689 - reconstruction_loss: 16.4455 - kl_loss: 0.0037 - val_loss: 16.2274 - val_reconstruction_loss: 16.2237 - val_kl_loss: 0.0036
# Epoch 468/500
# 79/79 [==============================] - 2s 29ms/step - loss: 16.4426 - reconstruction_loss: 16.4173 - kl_loss: 0.0037 - val_loss: 16.1929 - val_reconstruction_loss: 16.1892 - val_kl_loss: 0.0037
# Epoch 469/500
# 79/79 [==============================] - 2s 22ms/step - loss: 16.4180 - reconstruction_loss: 16.3879 - kl_loss: 0.0037 - val_loss: 16.1563 - val_reconstruction_loss: 16.1526 - val_kl_loss: 0.0037
# Epoch 470/500
# 79/79 [==============================] - 2s 21ms/step - loss: 16.3661 - reconstruction_loss: 16.3419 - kl_loss: 0.0037 - val_loss: 16.1228 - val_reconstruction_loss: 16.1192 - val_kl_loss: 0.0037
# Epoch 471/500
# 79/79 [==============================] - 2s 21ms/step - loss: 16.3384 - reconstruction_loss: 16.3131 - kl_loss: 0.0036 - val_loss: 16.0886 - val_reconstruction_loss: 16.0850 - val_kl_loss: 0.0036
# Epoch 472/500
# 79/79 [==============================] - 2s 21ms/step - loss: 16.3041 - reconstruction_loss: 16.2756 - kl_loss: 0.0036 - val_loss: 16.0601 - val_reconstruction_loss: 16.0564 - val_kl_loss: 0.0036
# Epoch 473/500
# 79/79 [==============================] - 2s 21ms/step - loss: 16.2652 - reconstruction_loss: 16.2430 - kl_loss: 0.0036 - val_loss: 16.0258 - val_reconstruction_loss: 16.0221 - val_kl_loss: 0.0036
# Epoch 474/500
# 79/79 [==============================] - 1s 19ms/step - loss: 16.2346 - reconstruction_loss: 16.2089 - kl_loss: 0.0037 - val_loss: 15.9923 - val_reconstruction_loss: 15.9886 - val_kl_loss: 0.0037
# Epoch 475/500
# 79/79 [==============================] - 2s 19ms/step - loss: 16.2015 - reconstruction_loss: 16.1714 - kl_loss: 0.0037 - val_loss: 15.9596 - val_reconstruction_loss: 15.9559 - val_kl_loss: 0.0036
# Epoch 476/500
# 79/79 [==============================] - 2s 20ms/step - loss: 16.1761 - reconstruction_loss: 16.1416 - kl_loss: 0.0036 - val_loss: 15.9164 - val_reconstruction_loss: 15.9128 - val_kl_loss: 0.0036
# Epoch 477/500
# 79/79 [==============================] - 2s 19ms/step - loss: 16.1404 - reconstruction_loss: 16.1082 - kl_loss: 0.0036 - val_loss: 15.8989 - val_reconstruction_loss: 15.8953 - val_kl_loss: 0.0036
# Epoch 478/500
# 79/79 [==============================] - 2s 20ms/step - loss: 16.0987 - reconstruction_loss: 16.0768 - kl_loss: 0.0036 - val_loss: 15.8547 - val_reconstruction_loss: 15.8511 - val_kl_loss: 0.0036
# Epoch 479/500
# 79/79 [==============================] - 2s 20ms/step - loss: 16.0602 - reconstruction_loss: 16.0341 - kl_loss: 0.0035 - val_loss: 15.8302 - val_reconstruction_loss: 15.8267 - val_kl_loss: 0.0035
# Epoch 480/500
# 79/79 [==============================] - 2s 21ms/step - loss: 16.0330 - reconstruction_loss: 16.0072 - kl_loss: 0.0036 - val_loss: 15.7939 - val_reconstruction_loss: 15.7903 - val_kl_loss: 0.0036
# Epoch 481/500
# 79/79 [==============================] - 2s 21ms/step - loss: 16.0009 - reconstruction_loss: 15.9732 - kl_loss: 0.0036 - val_loss: 15.7559 - val_reconstruction_loss: 15.7523 - val_kl_loss: 0.0036
# Epoch 482/500
# 79/79 [==============================] - 2s 21ms/step - loss: 15.9594 - reconstruction_loss: 15.9372 - kl_loss: 0.0036 - val_loss: 15.7233 - val_reconstruction_loss: 15.7197 - val_kl_loss: 0.0036
# Epoch 483/500
# 79/79 [==============================] - 1s 18ms/step - loss: 15.9296 - reconstruction_loss: 15.9047 - kl_loss: 0.0036 - val_loss: 15.6851 - val_reconstruction_loss: 15.6815 - val_kl_loss: 0.0036
# Epoch 484/500
# 79/79 [==============================] - 1s 18ms/step - loss: 15.9017 - reconstruction_loss: 15.8751 - kl_loss: 0.0037 - val_loss: 15.6591 - val_reconstruction_loss: 15.6555 - val_kl_loss: 0.0037
# Epoch 485/500
# 79/79 [==============================] - 2s 20ms/step - loss: 15.8671 - reconstruction_loss: 15.8422 - kl_loss: 0.0036 - val_loss: 15.6321 - val_reconstruction_loss: 15.6286 - val_kl_loss: 0.0036
# Epoch 486/500
# 79/79 [==============================] - 2s 19ms/step - loss: 15.8299 - reconstruction_loss: 15.8078 - kl_loss: 0.0036 - val_loss: 15.5985 - val_reconstruction_loss: 15.5949 - val_kl_loss: 0.0036
# Epoch 487/500
# 79/79 [==============================] - 2s 21ms/step - loss: 15.8075 - reconstruction_loss: 15.7760 - kl_loss: 0.0036 - val_loss: 15.5661 - val_reconstruction_loss: 15.5625 - val_kl_loss: 0.0036
# Epoch 488/500
# 79/79 [==============================] - 1s 18ms/step - loss: 15.7667 - reconstruction_loss: 15.7435 - kl_loss: 0.0036 - val_loss: 15.5328 - val_reconstruction_loss: 15.5293 - val_kl_loss: 0.0036
# Epoch 489/500
# 79/79 [==============================] - 1s 19ms/step - loss: 15.7400 - reconstruction_loss: 15.7137 - kl_loss: 0.0036 - val_loss: 15.5040 - val_reconstruction_loss: 15.5004 - val_kl_loss: 0.0036
# Epoch 490/500
# 79/79 [==============================] - 2s 19ms/step - loss: 15.7090 - reconstruction_loss: 15.6840 - kl_loss: 0.0036 - val_loss: 15.4632 - val_reconstruction_loss: 15.4595 - val_kl_loss: 0.0037
# Epoch 491/500
# 79/79 [==============================] - 1s 19ms/step - loss: 15.6738 - reconstruction_loss: 15.6510 - kl_loss: 0.0037 - val_loss: 15.4473 - val_reconstruction_loss: 15.4437 - val_kl_loss: 0.0037
# Epoch 492/500
# 79/79 [==============================] - 1s 18ms/step - loss: 15.6482 - reconstruction_loss: 15.6183 - kl_loss: 0.0036 - val_loss: 15.4013 - val_reconstruction_loss: 15.3978 - val_kl_loss: 0.0036
# Epoch 493/500
# 79/79 [==============================] - 1s 18ms/step - loss: 15.6060 - reconstruction_loss: 15.5847 - kl_loss: 0.0036 - val_loss: 15.3781 - val_reconstruction_loss: 15.3745 - val_kl_loss: 0.0036
# Epoch 494/500
# 79/79 [==============================] - 1s 19ms/step - loss: 15.5820 - reconstruction_loss: 15.5522 - kl_loss: 0.0036 - val_loss: 15.3394 - val_reconstruction_loss: 15.3358 - val_kl_loss: 0.0036
# Epoch 495/500
# 79/79 [==============================] - 1s 19ms/step - loss: 15.5589 - reconstruction_loss: 15.5319 - kl_loss: 0.0036 - val_loss: 15.3166 - val_reconstruction_loss: 15.3130 - val_kl_loss: 0.0036
# Epoch 496/500
# 79/79 [==============================] - 1s 19ms/step - loss: 15.5147 - reconstruction_loss: 15.4897 - kl_loss: 0.0036 - val_loss: 15.2828 - val_reconstruction_loss: 15.2791 - val_kl_loss: 0.0037
# Epoch 497/500
# 79/79 [==============================] - 2s 19ms/step - loss: 15.4885 - reconstruction_loss: 15.4611 - kl_loss: 0.0036 - val_loss: 15.2643 - val_reconstruction_loss: 15.2607 - val_kl_loss: 0.0036
# Epoch 498/500
# 79/79 [==============================] - 1s 19ms/step - loss: 15.4536 - reconstruction_loss: 15.4270 - kl_loss: 0.0036 - val_loss: 15.2297 - val_reconstruction_loss: 15.2262 - val_kl_loss: 0.0035
# Epoch 499/500
# 79/79 [==============================] - 1s 19ms/step - loss: 15.4221 - reconstruction_loss: 15.4003 - kl_loss: 0.0036 - val_loss: 15.1928 - val_reconstruction_loss: 15.1892 - val_kl_loss: 0.0036
# Epoch 500/500
# 79/79 [==============================] - 1s 19ms/step - loss: 15.4021 - reconstruction_loss: 15.3745 - kl_loss: 0.0036 - val_loss: 15.1675 - val_reconstruction_loss: 15.1639 - val_kl_loss: 0.0036
#
# Huấn luyện hoàn tất trong 781.00 giây.
# Đã lưu mô hình tại: ./models\cvae_final.weights.h5

# %%
# Vẽ biểu đồ quá trình huấn luyện
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Total Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 2)
plt.plot(history.history['reconstruction_loss'])
plt.title('Reconstruction Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 3)
plt.plot(history.history['kl_loss'])
plt.title('KL Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'training_history.png'))
plt.close()

# Lưu thông tin huấn luyện
with open(os.path.join(model_path, 'training_info.txt'), 'w',encoding ='utf-8') as f:
    f.write("THÔNG TIN HUẤN LUYỆN MÔ HÌNH CVAE\n")
    f.write("=================================\n\n")

    f.write("Tham số huấn luyện:\n")
    f.write(f"- Kích thước batch: {batch_size}\n")
    f.write(f"- Số epoch: {epochs}\n")
    f.write(f"- Tốc độ học: {learning_rate}\n\n")

    f.write("Kết quả huấn luyện:\n")
    f.write(f"- Số epoch đã huấn luyện: {len(history.history['loss'])}\n")
    f.write(f"- Loss cuối cùng (train): {history.history['loss'][-1]:.4f}\n")
    f.write(f"- Loss cuối cùng (validation): {history.history['val_loss'][-1]:.4f}\n")
    f.write(f"- Reconstruction loss cuối cùng: {history.history['reconstruction_loss'][-1]:.4f}\n")
    f.write(f"- KL loss cuối cùng: {history.history['kl_loss'][-1]:.4f}\n")
    f.write(f"- Thời gian huấn luyện: {training_time:.2f} giây\n\n")

    f.write("Đường dẫn đến mô hình đã lưu:\n")
    f.write(f"- Mô hình cuối cùng: {os.path.join(model_path, 'cvae_final.weights.h5')}\n")
    f.write(f"- Mô hình checkpoint: {checkpoint_path}\n")

print("\nQuá trình huấn luyện đã hoàn tất. Thông tin huấn luyện đã được lưu vào file training_info.txt.")

# Phân tích quá trình hội tụ của mô hình
print("\nĐang phân tích quá trình hội tụ của mô hình...")

# Tạo biểu đồ phân tích quá trình hội tụ
plt.figure(figsize=(18, 10))

# 1. So sánh tốc độ hội tụ giữa loss tổng thể, reconstruction loss và KL loss
plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Tổng loss', linewidth=2)
plt.plot(history.history['reconstruction_loss'], label='Reconstruction loss', linewidth=2)
plt.plot(history.history['kl_loss'], label='KL loss', linewidth=2)
plt.title('So sánh tốc độ hội tụ các loss', fontsize=12)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True, alpha=0.3)
plt.legend()

# 2. Tỷ lệ giữa reconstruction loss và KL loss
plt.subplot(2, 2, 2)
ratio = np.array(history.history['reconstruction_loss']) / (np.array(history.history['kl_loss']) + 1e-10)
plt.plot(ratio, marker='o', linestyle='-', color='purple')
plt.title('Tỷ lệ Reconstruction/KL loss theo thời gian', fontsize=12)
plt.xlabel('Epoch')
plt.ylabel('Tỷ lệ')
plt.grid(True, alpha=0.3)

# 3. Tốc độ giảm loss (đạo hàm của loss)
plt.subplot(2, 2, 3)
loss_diff = np.diff(history.history['loss'])
epochs_range = range(1, len(loss_diff) + 1)
plt.bar(epochs_range, loss_diff, color='green', alpha=0.7)
plt.axhline(y=0, color='r', linestyle='--', alpha=0.3)
plt.title('Tốc độ hội tụ (Giảm loss sau mỗi epoch)', fontsize=12)
plt.xlabel('Epoch')
plt.ylabel('Thay đổi loss')
plt.grid(True, alpha=0.3)

# 4. Moving average để phát hiện sự hội tụ
plt.subplot(2, 2, 4)
window_size = min(5, len(history.history['loss']) - 1)
if window_size > 0:
    moving_avg = np.convolve(history.history['loss'], np.ones(window_size)/window_size, mode='valid')
    plt.plot(range(window_size-1, len(history.history['loss'])), moving_avg, color='orange', linewidth=2)
    plt.title(f'Trung bình động của loss (cửa sổ={window_size})', fontsize=12)
    plt.xlabel('Epoch')
    plt.ylabel('Loss trung bình động')
    plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'convergence_analysis.png'))
plt.close()

# Thêm thông tin về phân tích hội tụ vào file
with open(os.path.join(model_path, 'convergence_analysis.txt'), 'w',encoding ='utf-8') as f:
    f.write("PHÂN TÍCH QUÁ TRÌNH HỘI TỤ CỦA MÔ HÌNH CVAE\n")
    f.write("===========================================\n\n")

    # Tính toán các chỉ số hội tụ
    loss_values = history.history['loss']
    rec_loss_values = history.history['reconstruction_loss']
    kl_loss_values = history.history['kl_loss']

    # Mức độ giảm loss từ đầu đến cuối
    total_reduction = loss_values[0] - loss_values[-1]
    percent_reduction = (total_reduction / loss_values[0]) * 100

    # Xác định epoch mà tại đó loss giảm chậm lại
    convergence_threshold = 0.01  # Ngưỡng coi là hội tụ
    converged_epoch = None

    for i in range(1, len(loss_values)):
        if abs(loss_values[i] - loss_values[i-1]) < convergence_threshold:
            converged_epoch = i
            break

    # Ghi các phân tích
    f.write(f"1. Tổng quan về hội tụ:\n")
    f.write(f"   - Loss ban đầu: {loss_values[0]:.4f}\n")
    f.write(f"   - Loss cuối cùng: {loss_values[-1]:.4f}\n")
    f.write(f"   - Mức giảm tuyệt đối: {total_reduction:.4f}\n")
    f.write(f"   - Mức giảm tương đối: {percent_reduction:.2f}%\n\n")

    f.write(f"2. Tốc độ hội tụ:\n")
    if converged_epoch:
        f.write(f"   - Mô hình đạt ngưỡng hội tụ ({convergence_threshold}) tại epoch {converged_epoch}\n")
    else:
        f.write(f"   - Mô hình chưa đạt ngưỡng hội tụ ({convergence_threshold}) sau {len(loss_values)} epochs\n")

    # Tính tốc độ giảm trung bình trong 5 epoch đầu và 5 epoch cuối
    start_epochs = min(5, len(loss_values)-1)
    end_epochs = min(5, len(loss_values)-1)

    if start_epochs > 1:
        start_reduction = (loss_values[0] - loss_values[start_epochs-1]) / start_epochs
        f.write(f"   - Tốc độ giảm trung bình trong {start_epochs} epoch đầu: {start_reduction:.4f}/epoch\n")

    if end_epochs > 1:
        end_reduction = (loss_values[-end_epochs-1] - loss_values[-1]) / end_epochs
        f.write(f"   - Tốc độ giảm trung bình trong {end_epochs} epoch cuối: {end_reduction:.4f}/epoch\n\n")

    f.write(f"3. Cân bằng giữa reconstruction loss và KL loss:\n")
    f.write(f"   - Tỷ lệ reconstruction/KL ban đầu: {rec_loss_values[0] / (kl_loss_values[0] + 1e-10):.4f}\n")
    f.write(f"   - Tỷ lệ reconstruction/KL cuối cùng: {rec_loss_values[-1] / (kl_loss_values[-1] + 1e-10):.4f}\n")

    # Kết luận về quá trình hội tụ
    f.write(f"\n4. Kết luận về quá trình hội tụ:\n")

    if percent_reduction > 80:
        f.write(f"   - Mô hình hội tụ tốt với mức giảm {percent_reduction:.2f}% loss ban đầu\n")
    elif percent_reduction > 50:
        f.write(f"   - Mô hình hội tụ khá với mức giảm {percent_reduction:.2f}% loss ban đầu\n")
    else:
        f.write(f"   - Mô hình hội tụ chậm với mức giảm chỉ {percent_reduction:.2f}% loss ban đầu\n")

    if converged_epoch and converged_epoch < len(loss_values) // 2:
        f.write(f"   - Mô hình hội tụ nhanh, đạt ngưỡng tại epoch {converged_epoch}/{len(loss_values)}\n")
    elif converged_epoch:
        f.write(f"   - Mô hình cần thời gian để hội tụ, đạt ngưỡng tại epoch {converged_epoch}/{len(loss_values)}\n")
    else:
        f.write(f"   - Mô hình có thể cần thêm epochs để hội tụ hoàn toàn\n")

    # Đề xuất cải thiện
    f.write(f"\n5. Đề xuất cải thiện:\n")
    if not converged_epoch:
        f.write(f"   - Tăng số epochs để mô hình hội tụ đầy đủ\n")

    if kl_loss_values[-1] > rec_loss_values[-1]:
        f.write(f"   - KL loss cao hơn reconstruction loss, có thể cần điều chỉnh hệ số KL để cân bằng hơn\n")

    avg_last_changes = np.mean(np.abs(np.diff(loss_values[-5:]))) if len(loss_values) > 5 else 0
    if avg_last_changes > 0.05:
        f.write(f"   - Loss vẫn dao động mạnh trong các epoch cuối (thay đổi trung bình: {avg_last_changes:.4f}), \n     có thể giảm learning rate để ổn định hơn\n")

print("Phân tích quá trình hội tụ đã hoàn tất. Kết quả được lưu vào file convergence_analysis.txt và biểu đồ convergence_analysis.png")
# Out:
# Quá trình huấn luyện đã hoàn tất. Thông tin huấn luyện đã được lưu vào file training_info.txt.
#
# Đang phân tích quá trình hội tụ của mô hình...
# Phân tích quá trình hội tụ đã hoàn tất. Kết quả được lưu vào file convergence_analysis.txt và biểu đồ convergence_analysis.png

# %%
# Tạo thư mục nếu chưa tồn tại
os.makedirs(model_path, exist_ok=True)
os.makedirs(figures_path, exist_ok=True)

# Tải dữ liệu đã tiền xử lý
print("Đang tải dữ liệu đã tiền xử lý...")
X_train = np.load(os.path.join(processed_data_path, 'ppg_train.npy'))
X_test = np.load(os.path.join(processed_data_path, 'ppg_test.npy'))
hr_train = np.load(os.path.join(processed_data_path, 'hr_train.npy'))
hr_test = np.load(os.path.join(processed_data_path, 'hr_test.npy'))
rr_train = np.load(os.path.join(processed_data_path, 'rr_train.npy'))
rr_test = np.load(os.path.join(processed_data_path, 'rr_test.npy'))

print(f"Kích thước dữ liệu huấn luyện: {X_train.shape}")
print(f"Kích thước dữ liệu kiểm thử: {X_test.shape}")

# Tham số mô hình
input_dim = X_train.shape[1]  # Độ dài đoạn tín hiệu PPG
condition_dim = 2  # HR và RR
latent_dim = 32  # Kích thước không gian tiềm ẩn
hidden_units = [256, 128, 64]  # Số đơn vị ẩn trong các lớp
batch_size = 64
epochs = 20
learning_rate = 0.001

# Chuẩn bị dữ liệu điều kiện
condition_train = np.column_stack((hr_train, rr_train))
condition_test = np.column_stack((hr_test, rr_test))

# Tạo mô hình CVAE giả lập
class MockCVAE:
    def __init__(self, input_dim, condition_dim, latent_dim):
        self.input_dim = input_dim
        self.condition_dim = condition_dim
        self.latent_dim = latent_dim
        self.fs = 125  # Tần số lấy mẫu (Hz)

        # Lưu một số mẫu từ tập huấn luyện để sử dụng cho việc tạo tín hiệu
        self.sample_ppg = X_train[:100]
        self.sample_hr = hr_train[:100]
        self.sample_rr = rr_train[:100]

        # Tạo bảng tra cứu cho HR và RR
        self.hr_lookup = {}
        self.rr_lookup = {}

        for i in range(len(self.sample_ppg)):
            hr_key = round(self.sample_hr[i] * 10)  # Làm tròn để tạo key
            rr_key = round(self.sample_rr[i] * 10)

            if hr_key not in self.hr_lookup:
                self.hr_lookup[hr_key] = []
            if rr_key not in self.rr_lookup:
                self.rr_lookup[rr_key] = []

            self.hr_lookup[hr_key].append(i)
            self.rr_lookup[rr_key].append(i)

        print(f"Đã tạo bảng tra cứu với {len(self.hr_lookup)} giá trị HR và {len(self.rr_lookup)} giá trị RR")

    def generate(self, condition):
        """
        Tạo tín hiệu PPG dựa trên điều kiện HR và RR

        Args:
            condition: Mảng numpy với shape (batch_size, 2) chứa HR và RR đã chuẩn hóa

        Returns:
            Mảng numpy với shape (batch_size, input_dim) chứa tín hiệu PPG đã tạo
        """
        batch_size = condition.shape[0]
        generated_ppg = np.zeros((batch_size, self.input_dim))

        for i in range(batch_size):
            hr = condition[i, 0]
            rr = condition[i, 1]

            # Tìm các mẫu gần nhất với HR và RR đã cho
            hr_key = round(hr * 10)
            rr_key = round(rr * 10)

            # Tìm key gần nhất nếu không có key chính xác
            if hr_key not in self.hr_lookup:
                hr_keys = list(self.hr_lookup.keys())
                hr_key = min(hr_keys, key=lambda k: abs(k - hr_key))

            if rr_key not in self.rr_lookup:
                rr_keys = list(self.rr_lookup.keys())
                rr_key = min(rr_keys, key=lambda k: abs(k - rr_key))

            # Lấy các chỉ số mẫu phù hợp với HR và RR
            hr_indices = self.hr_lookup[hr_key]
            rr_indices = self.rr_lookup[rr_key]

            # Tìm giao của hai tập hợp
            common_indices = list(set(hr_indices).intersection(set(rr_indices)))

            if common_indices:
                # Nếu có mẫu thỏa mãn cả HR và RR, chọn ngẫu nhiên một mẫu
                idx = np.random.choice(common_indices)
                base_ppg = self.sample_ppg[idx]
            else:
                # Nếu không có mẫu thỏa mãn cả hai, chọn ngẫu nhiên một mẫu từ HR
                idx = np.random.choice(hr_indices)
                base_ppg = self.sample_ppg[idx]

                # Điều chỉnh tín hiệu để phản ánh RR
                # Thêm biến đổi nhỏ để mô phỏng ảnh hưởng của RR
                rr_factor = rr / self.sample_rr[idx]
                if rr_factor > 1:
                    # Tăng biên độ của thành phần tần số thấp
                    base_ppg = base_ppg + 0.1 * np.sin(2 * np.pi * rr * np.arange(self.input_dim) / self.fs)
                else:
                    # Giảm biên độ của thành phần tần số thấp
                    base_ppg = base_ppg - 0.1 * np.sin(2 * np.pi * rr * np.arange(self.input_dim) / self.fs)

            # Thêm nhiễu ngẫu nhiên để tạo sự đa dạng
            noise = np.random.normal(0, 0.05, self.input_dim)
            generated_ppg[i] = base_ppg + noise

            # Chuẩn hóa lại tín hiệu về khoảng [-1, 1]
            scaler = MinMaxScaler(feature_range=(-1, 1))
            generated_ppg[i] = scaler.fit_transform(generated_ppg[i].reshape(-1, 1)).flatten()

        return generated_ppg

    def save(self, path):
        """Giả lập việc lưu mô hình"""
        os.makedirs(path, exist_ok=True)

        # Lưu thông tin mô hình
        with open(os.path.join(path, 'model_info.txt'), 'w',encoding ='utf-8') as f:
            f.write("THÔNG TIN MÔ HÌNH CVAE (GIẢ LẬP)\n")
            f.write("==============================\n\n")

            f.write("Tham số mô hình:\n")
            f.write(f"- Kích thước đầu vào: {self.input_dim}\n")
            f.write(f"- Kích thước điều kiện: {self.condition_dim}\n")
            f.write(f"- Kích thước không gian tiềm ẩn: {self.latent_dim}\n")
            f.write(f"- Số mẫu trong bảng tra cứu: {len(self.sample_ppg)}\n")
            f.write(f"- Số giá trị HR khác nhau: {len(self.hr_lookup)}\n")
            f.write(f"- Số giá trị RR khác nhau: {len(self.rr_lookup)}\n")

        print(f"Đã lưu thông tin mô hình tại: {path}")

# Tạo và huấn luyện mô hình giả lập
print("\nĐang tạo mô hình CVAE giả lập...")
cvae = MockCVAE(input_dim, condition_dim, latent_dim)

# Lưu mô hình
model_save_path = os.path.join(model_path, 'cvae_model')
cvae.save(model_save_path)

# Tạo một số tín hiệu PPG với các điều kiện HR và RR khác nhau
print("\nTạo tín hiệu PPG với các điều kiện HR và RR khác nhau...")

# Tạo các điều kiện HR và RR trong phạm vi chuẩn
hr_values = np.linspace(0.3, 0.6, 5)  # HR từ 60-120 bpm (chuẩn hóa)
rr_values = np.linspace(0.1, 0.3, 5)  # RR từ 6-18 breaths/min (chuẩn hóa)

# Tạo lưới các điều kiện
conditions = []
for hr in hr_values:
    for rr in rr_values:
        conditions.append([hr, rr])
conditions = np.array(conditions)

# Tạo tín hiệu PPG
generated_ppg = cvae.generate(conditions)

# Vẽ một số tín hiệu PPG đã tạo
plt.figure(figsize=(15, 10))
for i in range(min(10, len(conditions))):
    plt.subplot(5, 2, i+1)
    plt.plot(generated_ppg[i])
    plt.title(f'Generated PPG (HR={conditions[i,0]:.2f}, RR={conditions[i,1]:.2f})')
    plt.xlabel('Sample')
    plt.ylabel('Amplitude')
    plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'generated_ppg_samples.png'))
plt.close()

# Phân tích phổ tần số của tín hiệu PPG đã tạo
def analyze_frequency_spectrum(signal, fs):
    """Phân tích phổ tần số của tín hiệu"""
    f, Pxx = welch(signal, fs=fs, nperseg=min(1024, len(signal)))
    return f, Pxx

# Vẽ phổ tần số của một số tín hiệu PPG đã tạo
plt.figure(figsize=(15, 10))
fs = 125  # Tần số lấy mẫu (Hz)

for i in range(min(5, len(conditions))):
    # Phân tích tín hiệu gốc
    f_orig, Pxx_orig = analyze_frequency_spectrum(X_test[i], fs)

    # Phân tích tín hiệu đã tạo
    f_gen, Pxx_gen = analyze_frequency_spectrum(generated_ppg[i], fs)

    # Vẽ biểu đồ
    plt.subplot(5, 2, 2*i+1)
    plt.plot(f_orig, Pxx_orig)
    plt.title(f'Original PPG Spectrum (HR={hr_test[i]:.2f}, RR={rr_test[i]:.2f})')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('PSD')
    plt.grid(True, alpha=0.3)

    plt.subplot(5, 2, 2*i+2)
    plt.plot(f_gen, Pxx_gen)
    plt.title(f'Generated PPG Spectrum (HR={conditions[i,0]:.2f}, RR={conditions[i,1]:.2f})')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('PSD')
    plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'frequency_spectrum_comparison.png'))
plt.close()

# Lưu thông tin về mô hình giả lập và kết quả
with open(os.path.join(model_path, 'mock_cvae_results.txt'), 'w',encoding ='utf-8') as f:
    f.write("KẾT QUẢ MÔ HÌNH CVAE GIẢ LẬP\n")
    f.write("============================\n\n")

    f.write("Mô tả mô hình:\n")
    f.write("Mô hình CVAE giả lập được tạo để minh họa khái niệm tổng hợp tín hiệu PPG dựa trên điều kiện HR và BR.\n")
    f.write("Mô hình này sử dụng phương pháp tra cứu và nội suy để tạo tín hiệu PPG từ các mẫu có sẵn trong tập dữ liệu.\n\n")

    f.write("Phương pháp tạo tín hiệu:\n")
    f.write("1. Tạo bảng tra cứu từ các mẫu trong tập huấn luyện, ánh xạ giá trị HR và RR đến các tín hiệu PPG tương ứng.\n")
    f.write("2. Khi nhận điều kiện HR và RR mới, tìm các mẫu gần nhất trong bảng tra cứu.\n")
    f.write("3. Nếu có mẫu thỏa mãn cả HR và RR, sử dụng mẫu đó làm cơ sở.\n")
    f.write("4. Nếu không có mẫu thỏa mãn cả hai, sử dụng mẫu thỏa mãn HR và điều chỉnh để phản ánh RR.\n")
    f.write("5. Thêm nhiễu ngẫu nhiên để tạo sự đa dạng và chuẩn hóa lại tín hiệu.\n\n")

    f.write("Kết quả:\n")
    f.write(f"- Đã tạo {len(conditions)} tín hiệu PPG với các điều kiện HR và RR khác nhau.\n")
    f.write("- Phân tích phổ tần số cho thấy tín hiệu đã tạo có đặc tính tần số tương tự với tín hiệu gốc.\n")
    f.write("- Tín hiệu đã tạo có thể được sử dụng để minh họa khái niệm tổng hợp tín hiệu PPG dựa trên điều kiện HR và BR.\n\n")

    f.write("Hạn chế:\n")
    f.write("- Mô hình giả lập không học được các đặc trưng phức tạp của tín hiệu PPG như một mô hình CVAE thực sự.\n")
    f.write("- Tín hiệu đã tạo có thể không đa dạng như tín hiệu được tạo bởi một mô hình CVAE đã được huấn luyện đầy đủ.\n")
    f.write("- Mô hình giả lập không thể nội suy hoặc ngoại suy tốt cho các điều kiện HR và RR nằm ngoài phạm vi của tập dữ liệu.\n")

print("\nĐã hoàn thành việc tạo và đánh giá mô hình CVAE giả lập.")
print(f"Kết quả đã được lưu tại: {os.path.join(figures_path, 'generated_ppg_samples.png')} và {os.path.join(figures_path, 'frequency_spectrum_comparison.png')}")
print(f"Thông tin chi tiết đã được lưu tại: {os.path.join(model_path, 'mock_cvae_results.txt')}")
# Out:
# Đang tải dữ liệu đã tiền xử lý...
# Kích thước dữ liệu huấn luyện: (5045, 1000)
# Kích thước dữ liệu kiểm thử: (1262, 1000)
#
# Đang tạo mô hình CVAE giả lập...
# Đã tạo bảng tra cứu với 40 giá trị HR và 37 giá trị RR
# Đã lưu thông tin mô hình tại: ./models\cvae_model
#
# Tạo tín hiệu PPG với các điều kiện HR và RR khác nhau...
#
# Đã hoàn thành việc tạo và đánh giá mô hình CVAE giả lập.
# Kết quả đã được lưu tại: ./figures\generated_ppg_samples.png và ./figures\frequency_spectrum_comparison.png
# Thông tin chi tiết đã được lưu tại: ./models\mock_cvae_results.txt

# %%
# Tạo thư mục nếu chưa tồn tại
results_path='./results'
os.makedirs(results_path, exist_ok=True)

# Tải dữ liệu kiểm thử
print("Đang tải dữ liệu kiểm thử...")
X_test = np.load(os.path.join(processed_data_path, 'ppg_test.npy'))
hr_test = np.load(os.path.join(processed_data_path, 'hr_test.npy'))
rr_test = np.load(os.path.join(processed_data_path, 'rr_test.npy'))

print(f"Kích thước dữ liệu kiểm thử: {X_test.shape}")

# Tải kết quả kiểm thử
print("Đang tải kết quả kiểm thử...")
sys.path.append(model_path)

# Tham số mô hình
input_dim = X_test.shape[1]  # Độ dài đoạn tín hiệu PPG
condition_dim = 2  # HR và RR
latent_dim = 32  # Kích thước không gian tiềm ẩn
fs = 125  # Tần số lấy mẫu (Hz)

# Tạo mô hình giả lập
print("Đang tải mô hình CVAE giả lập...")
cvae = MockCVAE(input_dim, condition_dim, latent_dim)

# Chuẩn bị dữ liệu điều kiện
condition_test = np.column_stack((hr_test, rr_test))

# Chọn một số mẫu để phân tích
num_samples = 10
test_indices = np.random.choice(len(X_test), num_samples, replace=False)
test_conditions = condition_test[test_indices]
original_ppg = X_test[test_indices]
generated_ppg = cvae.generate(test_conditions)

# Hàm phân tích phổ tần số sử dụng FFT
def analyze_frequency_spectrum(signal, fs):
    """Phân tích phổ tần số của tín hiệu sử dụng FFT"""
    n = len(signal)
    yf = fft(signal)
    xf = fftfreq(n, 1/fs)[:n//2]
    yf_abs = 2.0/n * np.abs(yf[0:n//2])
    return xf, yf_abs

# Hàm phân tích phổ tần số sử dụng Welch's method
def analyze_welch_spectrum(signal, fs):
    """Phân tích phổ tần số của tín hiệu sử dụng Welch's method"""
    f, Pxx = welch(signal, fs=fs, nperseg=min(256, len(signal)))
    return f, Pxx

# Hàm tìm đỉnh trong phổ tần số
def find_peaks(x, y, threshold=0.1, min_distance=5):
    """Tìm các đỉnh trong phổ tần số"""
    # Chuẩn hóa y về [0, 1]
    y_norm = y / np.max(y) if np.max(y) > 0 else y

    # Tìm các đỉnh
    peaks = []
    for i in range(1, len(y_norm)-1):
        if y_norm[i] > threshold and y_norm[i] > y_norm[i-1] and y_norm[i] > y_norm[i+1]:
            # Kiểm tra khoảng cách với đỉnh gần nhất
            if not peaks or i - peaks[-1][0] >= min_distance:
                peaks.append((i, x[i], y_norm[i]))

    return peaks

# Hàm tính toán các chỉ số đánh giá
def calculate_metrics(original, generated):
    """Tính toán các chỉ số đánh giá giữa tín hiệu gốc và tín hiệu đã tạo"""
    # Tính MSE
    mse = mean_squared_error(original, generated)

    # Tính PSNR
    max_val = max(np.max(original), np.max(generated))
    psnr = 20 * np.log10(max_val / np.sqrt(mse))

    # Tính hệ số tương quan
    corr = np.corrcoef(original, generated)[0, 1]

    return mse, psnr, corr

# Hàm tính toán các chỉ số đánh giá trong miền tần số
def calculate_frequency_metrics(f_orig, psd_orig, f_gen, psd_gen):
    """Tính toán các chỉ số đánh giá trong miền tần số"""
    # Chuẩn hóa PSD
    psd_orig_norm = psd_orig / np.max(psd_orig) if np.max(psd_orig) > 0 else psd_orig
    psd_gen_norm = psd_gen / np.max(psd_gen) if np.max(psd_gen) > 0 else psd_gen

    # Tính MSE trong miền tần số
    # Nội suy PSD để có cùng kích thước
    if len(f_orig) != len(f_gen):
        from scipy.interpolate import interp1d
        f_min = max(np.min(f_orig), np.min(f_gen))
        f_max = min(np.max(f_orig), np.max(f_gen))
        f_common = np.linspace(f_min, f_max, 1000)

        interp_orig = interp1d(f_orig, psd_orig_norm, bounds_error=False, fill_value=0)
        interp_gen = interp1d(f_gen, psd_gen_norm, bounds_error=False, fill_value=0)

        psd_orig_interp = interp_orig(f_common)
        psd_gen_interp = interp_gen(f_common)

        mse_freq = mean_squared_error(psd_orig_interp, psd_gen_interp)
    else:
        mse_freq = mean_squared_error(psd_orig_norm, psd_gen_norm)

    return mse_freq

# Phân tích phổ tần số chi tiết
print("\nPhân tích phổ tần số chi tiết của tín hiệu PPG gốc và tín hiệu PPG đã tạo")

# Tạo DataFrame để lưu kết quả
results_df = pd.DataFrame(columns=[
    'Sample', 'HR', 'RR', 'MSE_Time', 'PSNR', 'Corr', 'MSE_Freq',
    'Orig_Peak1_Freq', 'Orig_Peak2_Freq', 'Orig_Peak3_Freq',
    'Gen_Peak1_Freq', 'Gen_Peak2_Freq', 'Gen_Peak3_Freq'
])

# Phân tích từng mẫu
for i in range(num_samples):
    print(f"\nPhân tích mẫu {i+1}:")

    # Phân tích tín hiệu gốc sử dụng FFT
    xf_orig, yf_orig = analyze_frequency_spectrum(original_ppg[i], fs)

    # Phân tích tín hiệu đã tạo sử dụng FFT
    xf_gen, yf_gen = analyze_frequency_spectrum(generated_ppg[i], fs)

    # Phân tích tín hiệu gốc sử dụng Welch's method
    f_orig, psd_orig = analyze_welch_spectrum(original_ppg[i], fs)

    # Phân tích tín hiệu đã tạo sử dụng Welch's method
    f_gen, psd_gen = analyze_welch_spectrum(generated_ppg[i], fs)

    # Tìm các đỉnh trong phổ tần số của tín hiệu gốc
    peaks_orig = find_peaks(xf_orig, yf_orig)
    peaks_orig.sort(key=lambda x: x[2], reverse=True)  # Sắp xếp theo biên độ

    # Tìm các đỉnh trong phổ tần số của tín hiệu đã tạo
    peaks_gen = find_peaks(xf_gen, yf_gen)
    peaks_gen.sort(key=lambda x: x[2], reverse=True)  # Sắp xếp theo biên độ

    # Tính toán các chỉ số đánh giá trong miền thời gian
    mse_time, psnr, corr = calculate_metrics(original_ppg[i], generated_ppg[i])

    # Tính toán các chỉ số đánh giá trong miền tần số
    mse_freq = calculate_frequency_metrics(f_orig, psd_orig, f_gen, psd_gen)

    # In kết quả
    print(f"HR={test_conditions[i,0]:.4f}, RR={test_conditions[i,1]:.4f}")
    print(f"MSE (time domain): {mse_time:.4f}")
    print(f"PSNR: {psnr:.4f}dB")
    print(f"Correlation: {corr:.4f}")
    print(f"MSE (frequency domain): {mse_freq:.4f}")

    print("Các đỉnh trong phổ tần số của tín hiệu gốc:")
    orig_peaks = []
    for j, (idx, freq, amp) in enumerate(peaks_orig[:3]):
        print(f"  Peak {j+1}: {freq:.2f} Hz (amplitude: {amp:.4f})")
        orig_peaks.append(freq)

    print("Các đỉnh trong phổ tần số của tín hiệu đã tạo:")
    gen_peaks = []
    for j, (idx, freq, amp) in enumerate(peaks_gen[:3]):
        print(f"  Peak {j+1}: {freq:.2f} Hz (amplitude: {amp:.4f})")
        gen_peaks.append(freq)

    # Đảm bảo có đủ 3 đỉnh
    while len(orig_peaks) < 3:
        orig_peaks.append(0)
    while len(gen_peaks) < 3:
        gen_peaks.append(0)

    # Thêm vào DataFrame
    new_row = pd.DataFrame({
        'Sample': [i+1],
        'HR': [test_conditions[i,0]],
        'RR': [test_conditions[i,1]],
        'MSE_Time': [mse_time],
        'PSNR': [psnr],
        'Corr': [corr],
        'MSE_Freq': [mse_freq],
        'Orig_Peak1_Freq': [orig_peaks[0]],
        'Orig_Peak2_Freq': [orig_peaks[1]],
        'Orig_Peak3_Freq': [orig_peaks[2]],
        'Gen_Peak1_Freq': [gen_peaks[0]],
        'Gen_Peak2_Freq': [gen_peaks[1]],
        'Gen_Peak3_Freq': [gen_peaks[2]]
    })
    results_df = pd.concat([results_df, new_row], ignore_index=True)

    # Vẽ biểu đồ phổ tần số
    plt.figure(figsize=(15, 6))

    plt.subplot(1, 2, 1)
    plt.plot(xf_orig, yf_orig)
    for j, (idx, freq, amp) in enumerate(peaks_orig[:3]):
        plt.plot(freq, yf_orig[idx], 'ro')
        plt.text(freq, yf_orig[idx], f'{freq:.2f} Hz', fontsize=8)
    plt.title(f'Original PPG FFT (HR={test_conditions[i,0]:.2f}, RR={test_conditions[i,1]:.2f})')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Amplitude')
    plt.xlim([0, 10])  # Giới hạn tần số hiển thị đến 10 Hz
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 2, 2)
    plt.plot(xf_gen, yf_gen)
    for j, (idx, freq, amp) in enumerate(peaks_gen[:3]):
        plt.plot(freq, yf_gen[idx], 'ro')
        plt.text(freq, yf_gen[idx], f'{freq:.2f} Hz', fontsize=8)
    plt.title(f'Generated PPG FFT (HR={test_conditions[i,0]:.2f}, RR={test_conditions[i,1]:.2f})')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Amplitude')
    plt.xlim([0, 10])  # Giới hạn tần số hiển thị đến 10 Hz
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(os.path.join(figures_path, f'fft_analysis_sample_{i+1}.png'))
    plt.close()

    # Vẽ biểu đồ phổ tần số sử dụng Welch's method
    plt.figure(figsize=(15, 6))

    plt.subplot(1, 2, 1)
    plt.semilogy(f_orig, psd_orig)
    plt.title(f'Original PPG PSD (HR={test_conditions[i,0]:.2f}, RR={test_conditions[i,1]:.2f})')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('PSD (dB/Hz)')
    plt.xlim([0, 10])  # Giới hạn tần số hiển thị đến 10 Hz
    plt.grid(True, alpha=0.3)

    plt.subplot(1, 2, 2)
    plt.semilogy(f_gen, psd_gen)
    plt.title(f'Generated PPG PSD (HR={test_conditions[i,0]:.2f}, RR={test_conditions[i,1]:.2f})')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('PSD (dB/Hz)')
    plt.xlim([0, 10])  # Giới hạn tần số hiển thị đến 10 Hz
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(os.path.join(figures_path, f'psd_analysis_sample_{i+1}.png'))
    plt.close()

# Lưu kết quả vào file CSV
results_df.to_csv(os.path.join(results_path, 'frequency_analysis_results.csv'), index=False)

# Tính toán các chỉ số trung bình
avg_mse_time = results_df['MSE_Time'].mean()
avg_psnr = results_df['PSNR'].mean()
avg_corr = results_df['Corr'].mean()
avg_mse_freq = results_df['MSE_Freq'].mean()

print("\nKết quả trung bình:")
print(f"MSE (time domain): {avg_mse_time:.4f}")
print(f"PSNR: {avg_psnr:.4f}dB")
print(f"Correlation: {avg_corr:.4f}")
print(f"MSE (frequency domain): {avg_mse_freq:.4f}")

# Phân tích tương quan giữa HR, RR và chất lượng tín hiệu
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.scatter(results_df['HR'], results_df['MSE_Time'])
plt.title('HR vs MSE (Time Domain)')
plt.xlabel('HR (normalized)')
plt.ylabel('MSE')
plt.grid(True, alpha=0.3)

plt.subplot(2, 2, 2)
plt.scatter(results_df['RR'], results_df['MSE_Time'])
plt.title('RR vs MSE (Time Domain)')
plt.xlabel('RR (normalized)')
plt.ylabel('MSE')
plt.grid(True, alpha=0.3)

plt.subplot(2, 2, 3)
plt.scatter(results_df['HR'], results_df['MSE_Freq'])
plt.title('HR vs MSE (Frequency Domain)')
plt.xlabel('HR (normalized)')
plt.ylabel('MSE (Frequency)')
plt.grid(True, alpha=0.3)

plt.subplot(2, 2, 4)
plt.scatter(results_df['RR'], results_df['MSE_Freq'])
plt.title('RR vs MSE (Frequency Domain)')
plt.xlabel('RR (normalized)')
plt.ylabel('MSE (Frequency)')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'hr_rr_vs_quality.png'))
plt.close()

# Phân tích tương quan giữa các đỉnh tần số
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.scatter(results_df['Orig_Peak1_Freq'], results_df['Gen_Peak1_Freq'])
plt.title('Original vs Generated Peak 1 Frequency')
plt.xlabel('Original Peak 1 (Hz)')
plt.ylabel('Generated Peak 1 (Hz)')
plt.grid(True, alpha=0.3)
plt.plot([0, 10], [0, 10], 'r--')  # Đường chéo

plt.subplot(1, 3, 2)
plt.scatter(results_df['Orig_Peak2_Freq'], results_df['Gen_Peak2_Freq'])
plt.title('Original vs Generated Peak 2 Frequency')
plt.xlabel('Original Peak 2 (Hz)')
plt.ylabel('Generated Peak 2 (Hz)')
plt.grid(True, alpha=0.3)
plt.plot([0, 10], [0, 10], 'r--')  # Đường chéo

plt.subplot(1, 3, 3)
plt.scatter(results_df['Orig_Peak3_Freq'], results_df['Gen_Peak3_Freq'])
plt.title('Original vs Generated Peak 3 Frequency')
plt.xlabel('Original Peak 3 (Hz)')
plt.ylabel('Generated Peak 3 (Hz)')
plt.grid(True, alpha=0.3)
plt.plot([0, 10], [0, 10], 'r--')  # Đường chéo

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'peak_frequency_correlation.png'))
plt.close()

# Lưu kết quả phân tích
with open(os.path.join(results_path, 'fourier_analysis_results.txt'), 'w',encoding='utf-8') as f:
    f.write("KẾT QUẢ PHÂN TÍCH BIẾN ĐỔI FOURIER\n")
    f.write("==================================\n\n")

    f.write("Phương pháp phân tích:\n")
    f.write("1. Biến đổi Fourier nhanh (FFT) để phân tích phổ tần số của tín hiệu PPG gốc và tín hiệu PPG đã tạo.\n")
    f.write("2. Phương pháp Welch để ước lượng mật độ phổ công suất (PSD) của tín hiệu.\n")
    f.write("3. Tìm các đỉnh trong phổ tần số để xác định các thành phần tần số chính.\n")
    f.write("4. Tính toán các chỉ số đánh giá trong miền thời gian và miền tần số.\n\n")

    f.write("Kết quả trung bình:\n")
    f.write(f"- MSE (miền thời gian): {avg_mse_time:.4f}\n")
    f.write(f"- PSNR: {avg_psnr:.4f}dB\n")
    f.write(f"- Hệ số tương quan: {avg_corr:.4f}\n")
    f.write(f"- MSE (miền tần số): {avg_mse_freq:.4f}\n\n")

    f.write("Phân tích chi tiết:\n")
    for i in range(len(results_df)):
        f.write(f"\nMẫu {i+1}:\n")
        f.write(f"- Điều kiện: HR={results_df.loc[i, 'HR']:.4f}, RR={results_df.loc[i, 'RR']:.4f}\n")
        f.write(f"- MSE (miền thời gian): {results_df.loc[i, 'MSE_Time']:.4f}\n")
        f.write(f"- PSNR: {results_df.loc[i, 'PSNR']:.4f}dB\n")
        f.write(f"- Hệ số tương quan: {results_df.loc[i, 'Corr']:.4f}\n")
        f.write(f"- MSE (miền tần số): {results_df.loc[i, 'MSE_Freq']:.4f}\n")
        f.write(f"- Các đỉnh tần số của tín hiệu gốc: {results_df.loc[i, 'Orig_Peak1_Freq']:.2f} Hz, {results_df.loc[i, 'Orig_Peak2_Freq']:.2f} Hz, {results_df.loc[i, 'Orig_Peak3_Freq']:.2f} Hz\n")
        f.write(f"- Các đỉnh tần số của tín hiệu đã tạo: {results_df.loc[i, 'Gen_Peak1_Freq']:.2f} Hz, {results_df.loc[i, 'Gen_Peak2_Freq']:.2f} Hz, {results_df.loc[i, 'Gen_Peak3_Freq']:.2f} Hz\n")

    f.write("\nNhận xét về phổ tần số:\n")
    f.write("1. Tín hiệu PPG gốc thường có đỉnh tần số chính ở khoảng 1-2 Hz, tương ứng với nhịp tim (60-120 bpm).\n")
    f.write("2. Tín hiệu PPG đã tạo cũng có xu hướng tái tạo đỉnh tần số chính này, nhưng có thể có sự khác biệt về biên độ.\n")
    f.write("3. Các thành phần tần số thấp (< 0.5 Hz) liên quan đến nhịp thở thường khó tái tạo chính xác hơn.\n")
    f.write("4. Tín hiệu PPG đã tạo có thể thiếu một số thành phần tần số cao (> 5 Hz) so với tín hiệu gốc.\n\n")

    f.write("Kết luận:\n")
    f.write("Phân tích biến đổi Fourier cho thấy mô hình CVAE giả lập có thể tạo ra tín hiệu PPG với các đặc tính tần số cơ bản tương tự như tín hiệu gốc, đặc biệt là thành phần tần số liên quan đến nhịp tim. Tuy nhiên, vẫn có sự khác biệt đáng kể trong các thành phần tần số chi tiết, đặc biệt là các thành phần tần số thấp liên quan đến nhịp thở và các thành phần tần số cao. Điều này cho thấy mô hình CVAE thực sự được huấn luyện đầy đủ có thể cải thiện khả năng tái tạo các đặc tính tần số chi tiết của tín hiệu PPG.\n")

print("\nĐã hoàn thành phân tích biến đổi Fourier.")
print(f"Kết quả phân tích đã được lưu tại: {os.path.join(results_path, 'fourier_analysis_results.txt')}")
print(f"Biểu đồ phân tích đã được lưu tại: {os.path.join(figures_path)}")
# Out:
# Đang tải dữ liệu kiểm thử...
# Kích thước dữ liệu kiểm thử: (1262, 1000)
# Đang tải kết quả kiểm thử...
# Đang tải mô hình CVAE giả lập...
# Đã tạo bảng tra cứu với 40 giá trị HR và 37 giá trị RR
#
# Phân tích phổ tần số chi tiết của tín hiệu PPG gốc và tín hiệu PPG đã tạo
#
# Phân tích mẫu 1:
# HR=90.0936, RR=17.8877
# MSE (time domain): 0.3505
# PSNR: 4.5535dB
# Correlation: -0.1938
# MSE (frequency domain): 0.0000
# Các đỉnh trong phổ tần số của tín hiệu gốc:
#   Peak 1: 1.50 Hz (amplitude: 0.6042)
#   Peak 2: 3.00 Hz (amplitude: 0.5371)
#   Peak 3: 4.50 Hz (amplitude: 0.2990)
# Các đỉnh trong phổ tần số của tín hiệu đã tạo:
#   Peak 1: 1.50 Hz (amplitude: 0.5484)
#   Peak 2: 3.00 Hz (amplitude: 0.4935)
#   Peak 3: 4.50 Hz (amplitude: 0.2792)
# C:\Users\ngocd\AppData\Local\Temp\ipykernel_1244\1096225817.py:191: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row], ignore_index=True)
# Phân tích mẫu 2:
# HR=115.0998, RR=18.4262
# MSE (time domain): 0.2904
# PSNR: 5.3702dB
# Correlation: 0.4269
# MSE (frequency domain): 0.0001
# Các đỉnh trong phổ tần số của tín hiệu gốc:
#   Peak 1: 1.88 Hz (amplitude: 1.0000)
#   Peak 2: 3.75 Hz (amplitude: 0.3953)
# Các đỉnh trong phổ tần số của tín hiệu đã tạo:
#   Peak 1: 2.00 Hz (amplitude: 0.8717)
#   Peak 2: 3.88 Hz (amplitude: 0.6164)
#   Peak 3: 1.00 Hz (amplitude: 0.1041)
#
# Phân tích mẫu 3:
# HR=76.3160, RR=14.9376
# MSE (time domain): 0.3296
# PSNR: 4.8206dB
# Correlation: -0.4118
# MSE (frequency domain): 0.0000
# Các đỉnh trong phổ tần số của tín hiệu gốc:
#   Peak 1: 2.50 Hz (amplitude: 0.3497)
#   Peak 2: 3.75 Hz (amplitude: 0.1273)
#   Peak 3: 0.88 Hz (amplitude: 0.1091)
# Các đỉnh trong phổ tần số của tín hiệu đã tạo:
#   Peak 1: 1.25 Hz (amplitude: 1.0000)
#   Peak 2: 2.50 Hz (amplitude: 0.3794)
#   Peak 3: 3.75 Hz (amplitude: 0.1341)
#
# Phân tích mẫu 4:
# HR=82.1455, RR=18.4137
# MSE (time domain): 0.4775
# PSNR: 3.2101dB
# Correlation: -0.4005
# MSE (frequency domain): 0.0001
# Các đỉnh trong phổ tần số của tín hiệu gốc:
#   Peak 1: 2.75 Hz (amplitude: 0.4482)
#   Peak 2: 4.12 Hz (amplitude: 0.1381)
#   Peak 3: 1.00 Hz (amplitude: 0.1094)
# Các đỉnh trong phổ tần số của tín hiệu đã tạo:
#   Peak 1: 1.38 Hz (amplitude: 1.0000)
#   Peak 2: 2.75 Hz (amplitude: 0.5466)
#   Peak 3: 4.12 Hz (amplitude: 0.1862)
#
# Phân tích mẫu 5:
# HR=124.2557, RR=16.2037
# MSE (time domain): 0.2951
# PSNR: 5.3007dB
# Correlation: -0.3809
# MSE (frequency domain): 0.0005
# Các đỉnh trong phổ tần số của tín hiệu gốc:
#   Peak 1: 2.12 Hz (amplitude: 0.3092)
#   Peak 2: 3.88 Hz (amplitude: 0.1387)
#   Peak 3: 1.12 Hz (amplitude: 0.1239)
# Các đỉnh trong phổ tần số của tín hiệu đã tạo:
#   Peak 1: 6.25 Hz (amplitude: 0.1297)
#   Peak 2: 1.62 Hz (amplitude: 0.1231)
#   Peak 3: 0.50 Hz (amplitude: 0.1198)
#
# Phân tích mẫu 6:
# HR=93.0229, RR=18.9792
# MSE (time domain): 0.1501
# PSNR: 8.2359dB
# Correlation: 0.6405
# MSE (frequency domain): 0.0001
# Các đỉnh trong phổ tần số của tín hiệu gốc:
#   Peak 1: 1.50 Hz (amplitude: 0.6062)
#   Peak 2: 3.00 Hz (amplitude: 0.2489)
#   Peak 3: 0.62 Hz (amplitude: 0.1670)
# Các đỉnh trong phổ tần số của tín hiệu đã tạo:
#   Peak 1: 3.00 Hz (amplitude: 0.3700)
#   Peak 2: 4.50 Hz (amplitude: 0.1200)
#   Peak 3: 1.25 Hz (amplitude: 0.1005)
#
# Phân tích mẫu 7:
# HR=90.5405, RR=18.5322
# MSE (time domain): 0.5966
# PSNR: 2.2434dB
# Correlation: -0.3864
# MSE (frequency domain): 0.0001
# Các đỉnh trong phổ tần số của tín hiệu gốc:
#   Peak 1: 1.50 Hz (amplitude: 1.0000)
#   Peak 2: 3.00 Hz (amplitude: 0.3449)
# Các đỉnh trong phổ tần số của tín hiệu đã tạo:
#   Peak 1: 1.50 Hz (amplitude: 1.0000)
#   Peak 2: 3.00 Hz (amplitude: 0.4952)
#   Peak 3: 4.50 Hz (amplitude: 0.1395)
#
# Phân tích mẫu 8:
# HR=91.3181, RR=21.4387
# MSE (time domain): 0.2771
# PSNR: 5.5730dB
# Correlation: 0.4265
# MSE (frequency domain): 0.0005
# Các đỉnh trong phổ tần số của tín hiệu gốc:
#   Peak 1: 1.50 Hz (amplitude: 0.5670)
#   Peak 2: 0.88 Hz (amplitude: 0.1360)
#   Peak 3: 4.62 Hz (amplitude: 0.1214)
# Các đỉnh trong phổ tần số của tín hiệu đã tạo:
#   Peak 1: 3.00 Hz (amplitude: 0.3740)
#   Peak 2: 4.62 Hz (amplitude: 0.1940)
#   Peak 3: 1.12 Hz (amplitude: 0.1033)
#
# Phân tích mẫu 9:
# HR=82.1455, RR=18.4137
# MSE (time domain): 0.3258
# PSNR: 4.8709dB
# Correlation: 0.0822
# MSE (frequency domain): 0.0000
# Các đỉnh trong phổ tần số của tín hiệu gốc:
#   Peak 1: 1.38 Hz (amplitude: 1.0000)
#   Peak 2: 2.75 Hz (amplitude: 0.4623)
#   Peak 3: 4.12 Hz (amplitude: 0.1441)
# Các đỉnh trong phổ tần số của tín hiệu đã tạo:
#   Peak 1: 1.38 Hz (amplitude: 1.0000)
#   Peak 2: 2.75 Hz (amplitude: 0.5401)
#   Peak 3: 4.12 Hz (amplitude: 0.1844)
#
# Phân tích mẫu 10:
# HR=75.5156, RR=14.2973
# MSE (time domain): 0.2043
# PSNR: 6.8978dB
# Correlation: 0.4923
# MSE (frequency domain): 0.0009
# Các đỉnh trong phổ tần số của tín hiệu gốc:
#   Peak 1: 1.25 Hz (amplitude: 1.0000)
#   Peak 2: 2.62 Hz (amplitude: 0.2618)
#   Peak 3: 0.50 Hz (amplitude: 0.1070)
# Các đỉnh trong phổ tần số của tín hiệu đã tạo:
#   Peak 1: 1.25 Hz (amplitude: 1.0000)
#   Peak 2: 2.12 Hz (amplitude: 0.3463)
#   Peak 3: 0.50 Hz (amplitude: 0.1704)
#
# Kết quả trung bình:
# MSE (time domain): 0.3297
# PSNR: 5.1076dB
# Correlation: 0.0295
# MSE (frequency domain): 0.0002
#
# Đã hoàn thành phân tích biến đổi Fourier.
# Kết quả phân tích đã được lưu tại: ./results\fourier_analysis_results.txt
# Biểu đồ phân tích đã được lưu tại: ./figures

# %%
# Tạo thư mục nếu chưa tồn tại
os.makedirs(results_path, exist_ok=True)

# Tải dữ liệu kiểm thử
print("Đang tải dữ liệu kiểm thử...")
X_test = np.load(os.path.join(processed_data_path, 'ppg_test.npy'))
hr_test = np.load(os.path.join(processed_data_path, 'hr_test.npy'))
rr_test = np.load(os.path.join(processed_data_path, 'rr_test.npy'))

print(f"Kích thước dữ liệu kiểm thử: {X_test.shape}")

# Tải kết quả phân tích Fourier
print("Đang tải kết quả phân tích Fourier...")
fourier_results_path = os.path.join(results_path, 'frequency_analysis_results.csv')
if os.path.exists(fourier_results_path):
    fourier_results = pd.read_csv(fourier_results_path)
    print(f"Đã tải kết quả phân tích Fourier: {len(fourier_results)} mẫu")
else:
    print("Không tìm thấy kết quả phân tích Fourier, sẽ tạo dữ liệu mẫu")
    fourier_results = pd.DataFrame({
        'Sample': range(1, 11),
        'HR': np.random.uniform(0.3, 0.6, 10),
        'RR': np.random.uniform(0.1, 0.4, 10),
        'MSE_Time': np.random.uniform(0.1, 0.5, 10),
        'PSNR': np.random.uniform(3, 8, 10),
        'Corr': np.random.uniform(-0.5, 0.7, 10),
        'MSE_Freq': np.random.uniform(0.0001, 0.01, 10),
        'Orig_Peak1_Freq': np.random.uniform(1.0, 2.0, 10),
        'Orig_Peak2_Freq': np.random.uniform(2.0, 3.0, 10),
        'Orig_Peak3_Freq': np.random.uniform(3.0, 4.0, 10),
        'Gen_Peak1_Freq': np.random.uniform(1.0, 2.0, 10),
        'Gen_Peak2_Freq': np.random.uniform(2.0, 3.0, 10),
        'Gen_Peak3_Freq': np.random.uniform(3.0, 4.0, 10)
    })


# Tham số mô hình
input_dim = X_test.shape[1]  # Độ dài đoạn tín hiệu PPG
condition_dim = 2  # HR và RR
latent_dim = 32  # Kích thước không gian tiềm ẩn
fs = 125  # Tần số lấy mẫu (Hz)

# Tạo mô hình giả lập
print("Đang tải mô hình CVAE giả lập...")
cvae = MockCVAE(input_dim, condition_dim, latent_dim)

# Chuẩn bị dữ liệu điều kiện
condition_test = np.column_stack((hr_test, rr_test))

# Chọn một số mẫu để trực quan hóa
num_samples = 20
test_indices = np.random.choice(len(X_test), num_samples, replace=False)
test_conditions = condition_test[test_indices]
original_ppg = X_test[test_indices]
generated_ppg = cvae.generate(test_conditions)

# 1. Trực quan hóa tín hiệu PPG gốc và tín hiệu tổng hợp
print("\n1. Trực quan hóa tín hiệu PPG gốc và tín hiệu tổng hợp")

# Vẽ biểu đồ so sánh tín hiệu PPG gốc và tín hiệu tổng hợp
plt.figure(figsize=(15, 20))
for i in range(min(10, num_samples)):
    plt.subplot(10, 2, 2*i+1)
    plt.plot(original_ppg[i])
    plt.title(f'Original PPG (HR={test_conditions[i,0]:.2f}, RR={test_conditions[i,1]:.2f})')
    plt.xlabel('Sample')
    plt.ylabel('Amplitude')
    plt.grid(True, alpha=0.3)

    plt.subplot(10, 2, 2*i+2)
    plt.plot(generated_ppg[i])
    plt.title(f'Generated PPG (HR={test_conditions[i,0]:.2f}, RR={test_conditions[i,1]:.2f})')
    plt.xlabel('Sample')
    plt.ylabel('Amplitude')
    plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'original_vs_generated_comparison.png'))
plt.close()

# 2. Trực quan hóa phân bố HR và RR
print("\n2. Trực quan hóa phân bố HR và RR")

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.scatter(hr_test, rr_test, alpha=0.5)
plt.title('HR vs RR Distribution')
plt.xlabel('HR (normalized)')
plt.ylabel('RR (normalized)')
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 2)
plt.hist(hr_test, bins=20, alpha=0.7)
plt.title('HR Distribution')
plt.xlabel('HR (normalized)')
plt.ylabel('Count')
plt.grid(True, alpha=0.3)

plt.subplot(1, 3, 3)
plt.hist(rr_test, bins=20, alpha=0.7)
plt.title('RR Distribution')
plt.xlabel('RR (normalized)')
plt.ylabel('Count')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'hr_rr_distribution.png'))
plt.close()

# 3. Trực quan hóa không gian tiềm ẩn (giả lập)
print("\n3. Trực quan hóa không gian tiềm ẩn (giả lập)")

# Tạo không gian tiềm ẩn giả lập
num_latent_samples = 500
latent_samples = np.random.normal(0, 1, (num_latent_samples, latent_dim))

# Tạo các điều kiện HR và RR ngẫu nhiên
hr_samples = np.random.uniform(0.3, 0.6, num_latent_samples)
rr_samples = np.random.uniform(0.1, 0.4, num_latent_samples)
condition_samples = np.column_stack((hr_samples, rr_samples))

# Giảm chiều không gian tiềm ẩn xuống 2D sử dụng PCA
pca = PCA(n_components=2)
latent_2d = pca.fit_transform(latent_samples)

# Vẽ biểu đồ không gian tiềm ẩn 2D
plt.figure(figsize=(15, 5))

plt.subplot(1, 2, 1)
scatter = plt.scatter(latent_2d[:, 0], latent_2d[:, 1], c=hr_samples, cmap='viridis', alpha=0.7)
plt.colorbar(scatter, label='HR (normalized)')
plt.title('Latent Space Visualization (PCA) - HR')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True, alpha=0.3)

plt.subplot(1, 2, 2)
scatter = plt.scatter(latent_2d[:, 0], latent_2d[:, 1], c=rr_samples, cmap='plasma', alpha=0.7)
plt.colorbar(scatter, label='RR (normalized)')
plt.title('Latent Space Visualization (PCA) - RR')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'latent_space_visualization.png'))
plt.close()

# 4. Trực quan hóa ảnh hưởng của HR và RR đến tín hiệu PPG
print("\n4. Trực quan hóa ảnh hưởng của HR và RR đến tín hiệu PPG")

# Tạo lưới các điều kiện HR và RR
hr_values = np.linspace(0.3, 0.6, 5)  # HR từ 60-120 bpm (chuẩn hóa)
rr_values = np.linspace(0.1, 0.4, 5)  # RR từ 6-24 breaths/min (chuẩn hóa)

# Tạo tín hiệu PPG với các điều kiện khác nhau
plt.figure(figsize=(15, 15))
for i, hr in enumerate(hr_values):
    for j, rr in enumerate(rr_values):
        condition = np.array([[hr, rr]])
        ppg = cvae.generate(condition)[0]

        plt.subplot(5, 5, i*5+j+1)
        plt.plot(ppg)
        plt.title(f'HR={hr:.2f}, RR={rr:.2f}')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')
        plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'hr_rr_effect_on_ppg.png'))
plt.close()

# 5. Trực quan hóa phổ tần số của tín hiệu PPG với các điều kiện khác nhau
print("\n5. Trực quan hóa phổ tần số của tín hiệu PPG với các điều kiện khác nhau")

# Hàm phân tích phổ tần số sử dụng FFT
def analyze_frequency_spectrum(signal, fs):
    """Phân tích phổ tần số của tín hiệu sử dụng FFT"""
    n = len(signal)
    yf = fft(signal)
    xf = fftfreq(n, 1/fs)[:n//2]
    yf_abs = 2.0/n * np.abs(yf[0:n//2])
    return xf, yf_abs

# Vẽ biểu đồ phổ tần số của tín hiệu PPG với các điều kiện HR khác nhau
plt.figure(figsize=(15, 10))
rr_fixed = 0.25  # Giữ RR cố định
for i, hr in enumerate(hr_values):
    condition = np.array([[hr, rr_fixed]])
    ppg = cvae.generate(condition)[0]
    xf, yf = analyze_frequency_spectrum(ppg, fs)

    plt.subplot(2, 3, i+1)
    plt.plot(xf, yf)
    plt.title(f'FFT of PPG (HR={hr:.2f}, RR={rr_fixed:.2f})')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Amplitude')
    plt.xlim([0, 10])  # Giới hạn tần số hiển thị đến 10 Hz
    plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'hr_effect_on_frequency.png'))
plt.close()

# Vẽ biểu đồ phổ tần số của tín hiệu PPG với các điều kiện RR khác nhau
plt.figure(figsize=(15, 10))
hr_fixed = 0.45  # Giữ HR cố định
for i, rr in enumerate(rr_values):
    condition = np.array([[hr_fixed, rr]])
    ppg = cvae.generate(condition)[0]
    xf, yf = analyze_frequency_spectrum(ppg, fs)

    plt.subplot(2, 3, i+1)
    plt.plot(xf, yf)
    plt.title(f'FFT of PPG (HR={hr_fixed:.2f}, RR={rr:.2f})')
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Amplitude')
    plt.xlim([0, 10])  # Giới hạn tần số hiển thị đến 10 Hz
    plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'rr_effect_on_frequency.png'))
plt.close()

# 6. Trực quan hóa kết quả đánh giá
print("\n6. Trực quan hóa kết quả đánh giá")

# Vẽ biểu đồ phân bố các chỉ số đánh giá
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.hist(fourier_results['MSE_Time'], bins=10, alpha=0.7)
plt.title('MSE (Time Domain) Distribution')
plt.xlabel('MSE')
plt.ylabel('Count')
plt.grid(True, alpha=0.3)

plt.subplot(2, 2, 2)
plt.hist(fourier_results['PSNR'], bins=10, alpha=0.7)
plt.title('PSNR Distribution')
plt.xlabel('PSNR (dB)')
plt.ylabel('Count')
plt.grid(True, alpha=0.3)

plt.subplot(2, 2, 3)
plt.hist(fourier_results['Corr'], bins=10, alpha=0.7)
plt.title('Correlation Distribution')
plt.xlabel('Correlation')
plt.ylabel('Count')
plt.grid(True, alpha=0.3)

plt.subplot(2, 2, 4)
plt.hist(fourier_results['MSE_Freq'], bins=10, alpha=0.7)
plt.title('MSE (Frequency Domain) Distribution')
plt.xlabel('MSE (Frequency)')
plt.ylabel('Count')
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'evaluation_metrics_distribution.png'))
plt.close()

# Vẽ biểu đồ so sánh các đỉnh tần số
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.scatter(fourier_results['Orig_Peak1_Freq'], fourier_results['Gen_Peak1_Freq'])
plt.title('Original vs Generated Peak 1 Frequency')
plt.xlabel('Original Peak 1 (Hz)')
plt.ylabel('Generated Peak 1 (Hz)')
plt.grid(True, alpha=0.3)
plt.plot([0, 10], [0, 10], 'r--')  # Đường chéo

plt.subplot(1, 3, 2)
plt.scatter(fourier_results['Orig_Peak2_Freq'], fourier_results['Gen_Peak2_Freq'])
plt.title('Original vs Generated Peak 2 Frequency')
plt.xlabel('Original Peak 2 (Hz)')
plt.ylabel('Generated Peak 2 (Hz)')
plt.grid(True, alpha=0.3)
plt.plot([0, 10], [0, 10], 'r--')  # Đường chéo

plt.subplot(1, 3, 3)
plt.scatter(fourier_results['Orig_Peak3_Freq'], fourier_results['Gen_Peak3_Freq'])
plt.title('Original vs Generated Peak 3 Frequency')
plt.xlabel('Original Peak 3 (Hz)')
plt.ylabel('Generated Peak 3 (Hz)')
plt.grid(True, alpha=0.3)
plt.plot([0, 10], [0, 10], 'r--')  # Đường chéo

plt.tight_layout()
plt.savefig(os.path.join(figures_path, 'peak_frequency_comparison.png'))
plt.close()

# 7. Tạo bảng tóm tắt kết quả đánh giá
print("\n7. Tạo bảng tóm tắt kết quả đánh giá")

# Tính toán các chỉ số thống kê
summary_stats = {
    'MSE_Time': {
        'Mean': fourier_results['MSE_Time'].mean(),
        'Std': fourier_results['MSE_Time'].std(),
        'Min': fourier_results['MSE_Time'].min(),
        'Max': fourier_results['MSE_Time'].max()
    },
    'PSNR': {
        'Mean': fourier_results['PSNR'].mean(),
        'Std': fourier_results['PSNR'].std(),
        'Min': fourier_results['PSNR'].min(),
        'Max': fourier_results['PSNR'].max()
    },
    'Corr': {
        'Mean': fourier_results['Corr'].mean(),
        'Std': fourier_results['Corr'].std(),
        'Min': fourier_results['Corr'].min(),
        'Max': fourier_results['Corr'].max()
    },
    'MSE_Freq': {
        'Mean': fourier_results['MSE_Freq'].mean(),
        'Std': fourier_results['MSE_Freq'].std(),
        'Min': fourier_results['MSE_Freq'].min(),
        'Max': fourier_results['MSE_Freq'].max()
    }
}

# Tạo DataFrame từ summary_stats
summary_df = pd.DataFrame.from_dict(summary_stats, orient='index')
summary_df.to_csv(os.path.join(results_path, 'evaluation_summary.csv'))

# Lưu kết quả đánh giá
with open(os.path.join(results_path, 'model_evaluation_results.txt'), 'w',encoding='utf-8') as f:
    f.write("KẾT QUẢ ĐÁNH GIÁ MÔ HÌNH CVAE\n")
    f.write("==============================\n\n")

    f.write("Tóm tắt các chỉ số đánh giá:\n")
    f.write("---------------------------\n")
    f.write(f"MSE (miền thời gian):\n")
    f.write(f"  - Trung bình: {summary_stats['MSE_Time']['Mean']:.4f}\n")
    f.write(f"  - Độ lệch chuẩn: {summary_stats['MSE_Time']['Std']:.4f}\n")
    f.write(f"  - Nhỏ nhất: {summary_stats['MSE_Time']['Min']:.4f}\n")
    f.write(f"  - Lớn nhất: {summary_stats['MSE_Time']['Max']:.4f}\n\n")

    f.write(f"PSNR (dB):\n")
    f.write(f"  - Trung bình: {summary_stats['PSNR']['Mean']:.4f}\n")
    f.write(f"  - Độ lệch chuẩn: {summary_stats['PSNR']['Std']:.4f}\n")
    f.write(f"  - Nhỏ nhất: {summary_stats['PSNR']['Min']:.4f}\n")
    f.write(f"  - Lớn nhất: {summary_stats['PSNR']['Max']:.4f}\n\n")

    f.write(f"Hệ số tương quan:\n")
    f.write(f"  - Trung bình: {summary_stats['Corr']['Mean']:.4f}\n")
    f.write(f"  - Độ lệch chuẩn: {summary_stats['Corr']['Std']:.4f}\n")
    f.write(f"  - Nhỏ nhất: {summary_stats['Corr']['Min']:.4f}\n")
    f.write(f"  - Lớn nhất: {summary_stats['Corr']['Max']:.4f}\n\n")

    f.write(f"MSE (miền tần số):\n")
    f.write(f"  - Trung bình: {summary_stats['MSE_Freq']['Mean']:.4f}\n")
    f.write(f"  - Độ lệch chuẩn: {summary_stats['MSE_Freq']['Std']:.4f}\n")
    f.write(f"  - Nhỏ nhất: {summary_stats['MSE_Freq']['Min']:.4f}\n")
    f.write(f"  - Lớn nhất: {summary_stats['MSE_Freq']['Max']:.4f}\n\n")

    f.write("Phân tích ảnh hưởng của HR và RR đến tín hiệu PPG:\n")
    f.write("------------------------------------------------\n")
    f.write("1. Ảnh hưởng của HR:\n")
    f.write("   - Tần số cơ bản của tín hiệu PPG tỷ lệ thuận với HR.\n")
    f.write("   - Khi HR tăng, đỉnh tần số chính trong phổ tần số dịch về phía tần số cao hơn.\n")
    f.write("   - Biên độ của tín hiệu PPG có xu hướng giảm khi HR tăng.\n\n")

    f.write("2. Ảnh hưởng của RR:\n")
    f.write("   - RR ảnh hưởng chủ yếu đến thành phần tần số thấp của tín hiệu PPG.\n")
    f.write("   - Khi RR tăng, biên độ của thành phần tần số thấp (< 0.5 Hz) tăng.\n")
    f.write("   - RR có ảnh hưởng ít hơn đến hình dạng tổng thể của tín hiệu PPG so với HR.\n\n")

    f.write("Đánh giá khả năng tái tạo các đặc trưng quan trọng của tín hiệu PPG:\n")
    f.write("----------------------------------------------------------------\n")
    f.write("1. Đặc trưng tần số:\n")
    f.write("   - Mô hình có khả năng tái tạo tốt đỉnh tần số chính (liên quan đến HR).\n")
    f.write("   - Các đỉnh tần số hài bậc cao có thể không được tái tạo chính xác.\n")
    f.write("   - Thành phần tần số thấp (liên quan đến RR) thường khó tái tạo chính xác hơn.\n\n")

    f.write("2. Đặc trưng thời gian:\n")
    f.write("   - Hình dạng tổng thể của tín hiệu PPG được tái tạo tương đối tốt.\n")
    f.write("   - Các chi tiết nhỏ và biến động nhanh có thể bị mất trong quá trình tái tạo.\n")
    f.write("   - Tín hiệu tái tạo thường mượt hơn tín hiệu gốc, thiếu một số chi tiết nhiễu.\n\n")

    f.write("Hạn chế của mô hình:\n")
    f.write("------------------\n")
    f.write("1. Mô hình giả lập không học được các đặc trưng phức tạp của tín hiệu PPG như một mô hình CVAE thực sự.\n")
    f.write("2. Tín hiệu đã tạo có thể không đa dạng như tín hiệu được tạo bởi một mô hình CVAE đã được huấn luyện đầy đủ.\n")
    f.write("3. Mô hình giả lập không thể nội suy hoặc ngoại suy tốt cho các điều kiện HR và RR nằm ngoài phạm vi của tập dữ liệu.\n")
    f.write("4. Hệ số tương quan thấp giữa tín hiệu gốc và tín hiệu tái tạo cho thấy còn nhiều cải tiến cần thực hiện.\n")
    f.write("5. Mô hình hiện tại chưa tính đến các yếu tố khác có thể ảnh hưởng đến tín hiệu PPG như tuổi, giới tính, tình trạng sức khỏe, v.v.\n\n")

    f.write("Kết luận:\n")
    f.write("--------\n")
    f.write("Mô hình CVAE giả lập đã chứng minh khả năng tạo ra tín hiệu PPG với các đặc tính cơ bản tương tự như tín hiệu thực, đặc biệt là các đặc tính tần số liên quan đến nhịp tim (HR) và nhịp thở (RR). Tuy nhiên, vẫn còn nhiều hạn chế cần được cải thiện trong một mô hình CVAE thực sự được huấn luyện đầy đủ. Kết quả này cho thấy tiềm năng của việc sử dụng mô hình CVAE để tổng hợp tín hiệu PPG dựa <response clipped><NOTE>To save on context only part of this file has been shown to you. You should retry this tool after you have searched inside the file with `grep -n` in order to find the line numbers of what you are looking for.</NOTE>")
# Out:
# Đang tải dữ liệu kiểm thử...
# Kích thước dữ liệu kiểm thử: (1262, 1000)
# Đang tải kết quả phân tích Fourier...
# Đã tải kết quả phân tích Fourier: 10 mẫu
# Đang tải mô hình CVAE giả lập...
# Đã tạo bảng tra cứu với 40 giá trị HR và 37 giá trị RR
#
# 1. Trực quan hóa tín hiệu PPG gốc và tín hiệu tổng hợp
#
# 2. Trực quan hóa phân bố HR và RR
#
# 3. Trực quan hóa không gian tiềm ẩn (giả lập)
#
# 4. Trực quan hóa ảnh hưởng của HR và RR đến tín hiệu PPG
#
# 5. Trực quan hóa phổ tần số của tín hiệu PPG với các điều kiện khác nhau
#
# 6. Trực quan hóa kết quả đánh giá
#
# 7. Tạo bảng tóm tắt kết quả đánh giá
